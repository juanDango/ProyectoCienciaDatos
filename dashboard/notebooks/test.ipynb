# %%
import pandas as pd
import requests

def consume_classifier_api(api_url, payload):
    """
    Consume el método classifier de una API.

    :param api_url: URL base de la API.
    :param payload: Datos que se enviarán en la solicitud POST (en formato JSON).
    :return: Respuesta de la API como un diccionario.
    """
    try:
        endpoint = f"{api_url}/classify"
        response = requests.post(endpoint, json=payload)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None
    except Exception as e:
        print(f"Error al consumir la API: {e}")
        return None

# %%
payload = [
  {
    "Company": "Ecopetrol S.A.",
    "Cash and Cash Equivalents": 12336115.05,
    "Export": "AU (0.06%), NL (1.84%), MY (2.39%), BN (0.25%), Iraq, PA (28.55%), PR (0.53%), JP (0.15%), CN (10.36%), BS (0.56%), SG (0.25%), IN (15.37%), MX (0.08%), Brazil, CI (1.57%), US (32.37%), PE (0.39%), ES (3.39%), CW (0.12%), CL (0.09%), EG (1.54%), FR (0.14%)",
    "Import": "UK (4.81%), Philippines, NL (4.66%), Austria, MY (0.02%), JP (0.02%), Sweden, CN (0.13%), BS (0.35%), NG (3.51%), IT (0.23%), CH (0.01%), Vietnam, Czech Republic, US (71.54%), ES (2.82%), FR (0.05%), Ireland, BE (4.66%), Taiwan, China, North Korea, RU (0.01%), KR (0.01%), South Africa, Portugal, Turkiye, CA (0.05%), GY (2.67%), Finland, DE (0.15%), Colombia, LT (0.66%), RO (0.01%), Singapore, AR (0.89%), IN (0.11%), MX (0.05%), BR (2.56%), Ukraine, Thailand, IL (0.02%), Slovakia, Chile, Hungary",
    "Industry (NAICS)": "Natural Gas Extraction(21113); Crude Petroleum Extraction(21112)",
    "Long term Debt": 90265519.23,
    "Net Sales Revenue Trend (%)": -10.28,
    "Number of Employees": "19,601 (2024)",
    "Operating Profit Trend (%)": -30.69,
    "Property, plant and equipment": 95171301.6,
    "Return on Assets (ROA) (%)": 8.26,
    "Return on Equity (ROE) (%)": 22.6,
    "Quick Ratio (x)": 1.34,
    "Short Term Debt": 15550007.72,
    "Total operating revenue": 142748516.61,
    "Fiscal Year": 2023,
    "Audited": "Audited",
    "Consolidated": "Consolidated",
    "Source": "Superfinanciera – IFRS",
    "EMIS ID": 1192567,
    "CO-NIT": "899999068",
    "ISIN": "COC04PA00016, US2791581091",
    "Ticker Symbol": "ECOPETROL"
  },
  {
    "Company": "Organizacion Terpel S.A.",
    "Cash and Cash Equivalents": 916490.75,
    "Export": "UK (0.04%), NL (47.11%), JM (0.17%), EC (3.59%), BB (0.03%), CR (0.13%), HT (0.02%), PA (4.19%), PR (0.09%), GF (0.22%), UY (0.01%), SV (0.07%), PY (0.05%), BS (0.16%), TC (0.01%), US (21.37%), PE (0.58%), ES (0.07%), CW (0.29%), EG (0.28%), BO (0.05%), CY (0.14%), IQ (0.01%), GT (0.02%), Guyana, BM (0.01%), VE (18.68%), SR (0.02%), AI (0.05%), AR (0.04%), Guadeloupe (French), AW (0.23%), MX (0.42%), BR (0.1%), HN",
    "Import": "DE (0.24%), Colombia, KR (0.01%), BR (0.2%), LT (0.01%), HU (0.1%), VE (3.16%), MX (0.05%), RO (0.13%), IN (0.02%), SK (0.15%), AR (0.26%), CZ (0.01%), North Korea, TW (0.01%), CA (0.27%), MY (0.01%), CL (0.01%), PL (0.12%), FR (0.01%), IT (0.29%), US (91.01%), UK (0.34%)",
    "Industry (NAICS)": "Petroleum and Petroleum Products Merchant Wholesalers(42472)",
    "Long term Debt": 4128162.15,
    "Net Sales Revenue Trend (%)": 0.37,
    "Number of Employees": "5,961 (2024)",
    "Operating Profit Trend (%)": 8.71,
    "Property, plant and equipment": 11264320.97,
    "Return on Assets (ROA) (%)": 11.64,
    "Return on Equity (ROE) (%)": 28.91,
    "Quick Ratio (x)": 1.12,
    "Short Term Debt": 2217605.94,
    "Total operating revenue": 36252719.63,
    "Fiscal Year": 2023,
    "Audited": "Audited",
    "Consolidated": "Consolidated",
    "Source": "Superfinanciera – IFRS",
    "EMIS ID": 1208163,
    "CO-NIT": "830095213",
    "ISIN": "COG20PA00021",
    "Ticker Symbol": "TERPEL"
  }
]

# %%
URL = "http://0.0.0.0:8000/"
result = consume_classifier_api(URL, payload)
result
# Out:
# [{'Company': 'Ecopetrol S.A.',
#   'Cash and Cash Equivalents': 12336115.05,
#   'Long term Debt': 90265519.23,
#   'Net Sales Revenue Trend (%)': -10.28,
#   'Operating Profit Trend (%)': -30.69,
#   'Property, plant and equipment': 95171301.6,
#   'Return on Assets (ROA) (%)': 8.26,
#   'Return on Equity (ROE) (%)': 22.6,
#   'Quick Ratio (x)': 1.34,
#   'Short Term Debt': 15550007.72,
#   'Total operating revenue': 142748516.61,
#   'Employees': 19601.0,
#   'Export_CN': 10.36,
#   'Import_CN': 0.13,
#   'Export_US': 32.37,
#   'Import_US': 71.54,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.08,
#   'Import_MX': 0.05,
#   'Export_ES': 3.39,
#   'Import_ES': 2.82,
#   'Export_DE': 0.0,
#   'Import_DE': 0.15,
#   'Export_BR': 0.0,
#   'Import_BR': 2.56,
#   'Export_PE': 0.39,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.23,
#   'Export_PA': 28.55,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 1.1118428052,
#   'Relative_Growth': 20.41,
#   'cluster': 4},
#  {'Company': 'Organizacion Terpel S.A.',
#   'Cash and Cash Equivalents': 916490.75,
#   'Long term Debt': 4128162.15,
#   'Net Sales Revenue Trend (%)': 0.37,
#   'Operating Profit Trend (%)': 8.71,
#   'Property, plant and equipment': 11264320.97,
#   'Return on Assets (ROA) (%)': 11.64,
#   'Return on Equity (ROE) (%)': 28.91,
#   'Quick Ratio (x)': 1.12,
#   'Short Term Debt': 2217605.94,
#   'Total operating revenue': 36252719.63,
#   'Employees': 5961.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 21.37,
#   'Import_US': 91.01,
#   'Export_EC': 3.59,
#   'Import_EC': 0.0,
#   'Export_MX': 0.42,
#   'Import_MX': 0.05,
#   'Export_ES': 0.07,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.24,
#   'Export_BR': 0.1,
#   'Import_BR': 0.2,
#   'Export_PE': 0.58,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.29,
#   'Export_PA': 4.19,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.5633511427,
#   'Relative_Growth': -8.34,
#   'cluster': 10}]

# %%
data_entrada = pd.read_excel("../datos/Export.xlsx", skiprows=7)
data_entrada = data_entrada[[
    "Company",
    "Cash and Cash Equivalents",    
    "Export",
    "Import",
    "Industry (NAICS)",
    "Long term Debt",
    "Net Sales Revenue Trend (%)",
    "Number of Employees",
    "Operating Profit Trend (%)",
    "Property, plant and equipment",
    "Return on Assets (ROA) (%)",
    "Return on Equity (ROE) (%)",
    "Quick Ratio (x)",
    "Short Term Debt",      
    "Total operating revenue",
]]

# %%
df_to_dict = data_entrada.dropna()

# %%
payload2 = df_to_dict.to_dict(orient="records")

# %%
payload2
# Out:
# [{'Company': 'Ecopetrol S.A.',
#   'Cash and Cash Equivalents': 12336115.05,
#   'Export': 'AU (0.06%), NL (1.84%), MY (2.39%), BN (0.25%), Iraq, PA (28.55%), PR (0.53%), JP (0.15%), CN (10.36%), BS (0.56%), SG (0.25%), IN (15.37%), MX (0.08%), Brazil, CI (1.57%), US (32.37%), PE (0.39%), ES (3.39%), CW (0.12%), CL (0.09%), EG (1.54%), FR (0.14%)',
#   'Import': 'UK (4.81%), Philippines, NL (4.66%), Austria, MY (0.02%), JP (0.02%), Sweden, CN (0.13%), BS (0.35%), NG (3.51%), IT (0.23%), CH (0.01%), Vietnam, Czech Republic, US (71.54%), ES (2.82%), FR (0.05%), Ireland, BE (4.66%), Taiwan, China, North Korea, RU (0.01%), KR (0.01%), South Africa, Portugal, Turkiye, CA (0.05%), GY (2.67%), Finland, DE (0.15%), Colombia, LT (0.66%), RO (0.01%), Singapore, AR (0.89%), IN (0.11%), MX (0.05%), BR (2.56%), Ukraine, Thailand, IL (0.02%), Slovakia, Chile, Hungary',
#   'Industry (NAICS)': 'Natural Gas Extraction(21113); Crude Petroleum Extraction(21112)',
#   'Long term Debt': 90265519.23,
#   'Net Sales Revenue Trend (%)': -10.28,
#   'Number of Employees': '19,601 (2024)',
#   'Operating Profit Trend (%)': -30.69,
#   'Property, plant and equipment': 95171301.6,
#   'Return on Assets (ROA) (%)': 8.26,
#   'Return on Equity (ROE) (%)': 22.6,
#   'Quick Ratio (x)': 1.34,
#   'Short Term Debt': 15550007.72,
#   'Total operating revenue': 142748516.61},
#  {'Company': 'Organizacion Terpel S.A.',
#   'Cash and Cash Equivalents': 916490.75,
#   'Export': 'UK (0.04%), NL (47.11%), JM (0.17%), EC (3.59%), BB (0.03%), CR (0.13%), HT (0.02%), PA (4.19%), PR (0.09%), GF (0.22%), UY (0.01%), SV (0.07%), PY (0.05%), BS (0.16%), TC (0.01%), US (21.37%), PE (0.58%), ES (0.07%), CW (0.29%), EG (0.28%), BO (0.05%), CY (0.14%), IQ (0.01%), GT (0.02%), Guyana, BM (0.01%), VE (18.68%), SR (0.02%), AI (0.05%), AR (0.04%), Guadeloupe (French), AW (0.23%), MX (0.42%), BR (0.1%), HN (0.03%), DO (1.61%), CL (0.11%)',
#   'Import': 'Philippines, NL (0.04%), Belgium, KR (1.6%), CA (0.24%), CN (0.38%), DE (0.45%), FI (0.05%), SE (0.02%), IN (0.24%), IT (0.08%), US (96.06%), PE (0.45%), ES (0.06%), Egypt, CL (0.03%), FR (0.3%)',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472); Gasoline Stations(4471)',
#   'Long term Debt': 3171446.29,
#   'Net Sales Revenue Trend (%)': 2.17,
#   'Number of Employees': '1,582 (2024)',
#   'Operating Profit Trend (%)': 10.06,
#   'Property, plant and equipment': 3939357.24,
#   'Return on Assets (ROA) (%)': 3.06,
#   'Return on Equity (ROE) (%)': 10.37,
#   'Quick Ratio (x)': 0.89,
#   'Short Term Debt': 1088524.14,
#   'Total operating revenue': 36252719.63},
#  {'Company': 'D1 S A S',
#   'Cash and Cash Equivalents': 718512.83,
#   'Export': 'EC (100%)',
#   'Import': 'UK (1.1%), ID (0.82%), EC (22.67%), PT (1.16%), TR (4.23%), CN (8.14%), DE (3.29%), GR (0.62%), CO (9.41%), RO (0.02%), AR (1.78%), IN (0.02%), IT (11.84%), PL (5.17%), BR (0.12%), IL (0.18%), PE (2.55%), ES (20.69%), CL (5.82%), FR (0.37%)',
#   'Industry (NAICS)': 'Grocery Stores(4451)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 24.88,
#   'Number of Employees': '19,780 (2023)',
#   'Operating Profit Trend (%)': 1.75,
#   'Property, plant and equipment': 3379990.01,
#   'Return on Assets (ROA) (%)': 5.19,
#   'Return on Equity (ROE) (%)': 167.99,
#   'Quick Ratio (x)': 0.33,
#   'Short Term Debt': 9555.73,
#   'Total operating revenue': 17424130.56},
#  {'Company': 'Enel Colombia S.A. E.S.P.',
#   'Cash and Cash Equivalents': 1629477.08,
#   'Export': 'PA (99.92%), US (0.08%)',
#   'Import': 'Tunisia, HK (0.05%), AT (0.37%), TW (0.02%), South Korea, PT (2.1%), TR (2.05%), Japan, CN (80.97%), DE (0.07%), Bulgaria, Romania, Poland, AR (0.77%), CH (0.01%), IN (0.57%), IT (4.27%), MX (0.14%), Czech Republic, BR (1.25%), US (0.43%), Thailand, PE (1.02%), Israel, ES (5.55%), CL (0.33%), France, HU (0.03%)',
#   'Industry (NAICS)': 'Electric Power Generation(22111)',
#   'Long term Debt': 7253638.57,
#   'Net Sales Revenue Trend (%)': 37.18,
#   'Number of Employees': '2,601 (2024)',
#   'Operating Profit Trend (%)': -3.57,
#   'Property, plant and equipment': 21758779.81,
#   'Return on Assets (ROA) (%)': 6.6,
#   'Return on Equity (ROE) (%)': 13.98,
#   'Quick Ratio (x)': 0.74,
#   'Short Term Debt': 2180692.21,
#   'Total operating revenue': 16724866.7},
#  {'Company': 'Drummond Ltd',
#   'Cash and Cash Equivalents': 169861.35,
#   'Export': 'NL (16.6%), HK (0.05%), TW (3.98%), KR (5.43%), PA (1.66%), TR (5.5%), PR (2.36%), JP (6.49%), CA (0.82%), GT (0.61%), CN (3.08%), DE (0.87%), MA (0.38%), PL (14.55%), AR (0.24%), IN (0.38%), MX (15.17%), BR (2.8%), US (3.74%), IL (4.68%), ES (2.43%), DO (1.78%), CL (6.4%)',
#   'Import': 'AT (0.04%), DK (0.07%), JP (2.54%), Malta, IT (1.6%), Croatia, CZ (0.08%), ES (0.57%), Belarus, FR (0.1%), AU (0.81%), BE (0.08%), Estonia, Norway, KR (0.34%), ZA (0.01%), Portugal, TR (0.14%), CA (0.94%), SI (0.01%), Colombia, PL (0.03%), Bosnia and Herzegovina, Ukraine, TH (0.01%), CL (0.03%), Ethiopia, UK (0.6%), PH (0.02%), NL (0.04%), Hong Kong SAR, China, MY (0.15%), Myanmar, CN (3.14%), SE (0.82%), BG (0.01%), Uruguay, Nigeria, CH (0.28%), VN (0.04%), Ivory Coast, US (66.98%), Sri Lanka, ID (0.06%), IE (0.01%), TW (0.23%), North Korea, RU (1.93%), FI (0.16%), DE (13.18%), Luxembourg, Pakistan, Lithuania, RO (0.03%), IN (0.43%), Argentina, SG (0.02%), MX (3.85%), Honduras, BR (0.56%), Israel, SB (0.01%), Slovakia, Syria, HU (0.01%), DO (0.04%), Bangladesh',
#   'Industry (NAICS)': 'Support Activities for Oil and Gas Operations(213112); Coal Mining(21211)',
#   'Long term Debt': 150353.59,
#   'Net Sales Revenue Trend (%)': 1.55,
#   'Number of Employees': '5,340 (2024)',
#   'Operating Profit Trend (%)': 6.54,
#   'Property, plant and equipment': 5480302.25,
#   'Return on Assets (ROA) (%)': 27.61,
#   'Return on Equity (ROE) (%)': 40.46,
#   'Quick Ratio (x)': 1.8,
#   'Short Term Debt': 106914.23,
#   'Total operating revenue': 15424348.8},
#  {'Company': 'Comunicacion Celular S A Comcel S A',
#   'Cash and Cash Equivalents': 354995.14,
#   'Export': 'MX (71.23%), US (4.02%), SV (24.75%)',
#   'Import': 'CN (62.77%), IE (6.59%), Taiwan, China, MY (0.08%), IN (0.15%), CH (0.03%), MX (6.26%), NO (0.36%), KR (0.07%), VN (7.25%), US (2.52%), TH (13.87%), CA (0.01%), FR (0.04%)',
#   'Industry (NAICS)': 'Wireless Telecommunications Carriers (except Satellite)(517312)',
#   'Long term Debt': 1745160.97,
#   'Net Sales Revenue Trend (%)': 1.64,
#   'Number of Employees': '9,492 (2024)',
#   'Operating Profit Trend (%)': -22.92,
#   'Property, plant and equipment': 11498788.34,
#   'Return on Assets (ROA) (%)': 5.86,
#   'Return on Equity (ROE) (%)': 13.85,
#   'Quick Ratio (x)': 1.17,
#   'Short Term Debt': 520160.92,
#   'Total operating revenue': 14853248.62},
#  {'Company': 'Jeronimo Martins Colombia Sas',
#   'Cash and Cash Equivalents': 445768.23,
#   'Export': 'EC (46.13%), IT (53.87%)',
#   'Import': 'DE (5.66%), CN (28.91%), BE (0.22%), PL (18.93%), IT (11.19%), VN (2.83%), US (0.76%), PT (11.47%), ES (13.43%), CA (0.32%), CL (6.03%), FR (0.25%)',
#   'Industry (NAICS)': 'Grocery Stores(4451)',
#   'Long term Debt': 699134.53,
#   'Net Sales Revenue Trend (%)': 43.27,
#   'Number of Employees': '12,482 (2024)',
#   'Operating Profit Trend (%)': 1549.59,
#   'Property, plant and equipment': 3296243.22,
#   'Return on Assets (ROA) (%)': -9.21,
#   'Return on Equity (ROE) (%)': -522.59,
#   'Quick Ratio (x)': 0.14,
#   'Short Term Debt': 1950722.58,
#   'Total operating revenue': 12352070.91},
#  {'Company': 'Colombiana de Comercio S.A.',
#   'Cash and Cash Equivalents': 467037.66,
#   'Export': 'MX (4.45%), UY (66.6%), SV (0.8%), CR (1.82%), IN (2.26%), BO (24.07%)',
#   'Import': 'United Kingdom, PH (0.05%), Nicaragua, EC (0.52%), MY (1.03%), JP (0.71%), CN (80.87%), IT (0.06%), VN (1.09%), US (2.62%), PE (0.08%), ES (0.2%), ID (0.24%), BE (0.07%), TW (0.09%), KR (0.05%), PT (0.01%), TR (0.02%), Canada, GR (0.07%), DE (1.25%), PK (0.13%), Venezuela, IN (2.51%), Argentina, MX (6.43%), HN (0.86%), BR (0.39%), IL (0.01%), TH (0.6%), CL (0.01%), BD (0.03%)',
#   'Industry (NAICS)': 'Merchant Wholesalers, Nondurable Goods(424)',
#   'Long term Debt': 196537.93,
#   'Net Sales Revenue Trend (%)': -0.08,
#   'Number of Employees': '12,772 (2024)',
#   'Operating Profit Trend (%)': -9.82,
#   'Property, plant and equipment': 1341359.38,
#   'Return on Assets (ROA) (%)': 5.35,
#   'Return on Equity (ROE) (%)': 11.87,
#   'Quick Ratio (x)': 0.62,
#   'Short Term Debt': 369297.09,
#   'Total operating revenue': 11148835.22},
#  {'Company': 'Kopps Commercial S.A.S',
#   'Cash and Cash Equivalents': 3953511.43,
#   'Export': ' ',
#   'Import': 'MX (15.59%), US (84.41%)',
#   'Industry (NAICS)': 'Tobacco and Tobacco Product Merchant Wholesalers(42494); Beer, Wine, and Distilled Alcoholic Beverage Merchant Wholesalers(4248)',
#   'Long term Debt': 463100.06,
#   'Net Sales Revenue Trend (%)': 11.77,
#   'Number of Employees': '654 (2024)',
#   'Operating Profit Trend (%)': 12.06,
#   'Property, plant and equipment': 752873.87,
#   'Return on Assets (ROA) (%)': 16.39,
#   'Return on Equity (ROE) (%)': 83.06,
#   'Quick Ratio (x)': 1.17,
#   'Short Term Debt': 52318.82,
#   'Total operating revenue': 10635671.37},
#  {'Company': 'Primax Colombia S.A.',
#   'Cash and Cash Equivalents': 94148.67,
#   'Export': 'SV (5.36%), EC (34.4%), HN (1.92%), PA (7.83%), PE (30.86%), BZ (1.47%), GT (18.16%)',
#   'Import': 'CN (8.56%), US (89.56%), TW (0.88%), CA (1%)',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472)',
#   'Long term Debt': 434602.55,
#   'Net Sales Revenue Trend (%)': 16.43,
#   'Number of Employees': '148 (2024)',
#   'Operating Profit Trend (%)': 36.87,
#   'Property, plant and equipment': 785141.85,
#   'Return on Assets (ROA) (%)': 4.32,
#   'Return on Equity (ROE) (%)': 16.17,
#   'Quick Ratio (x)': 0.48,
#   'Short Term Debt': 174446.95,
#   'Total operating revenue': 9045379.71},
#  {'Company': 'Grupo Energia Bogota S.A.E.S.P.',
#   'Cash and Cash Equivalents': 2289704.0,
#   'Export': 'AT (83.53%), FR (16.47%)',
#   'Import': 'SE (0.65%), DE (7.01%), CN (7.29%), AT (0.05%), IT (2.02%), IN (56.39%), BR (23.89%), US (0.02%), ES (1.73%), FR (0.95%)',
#   'Industry (NAICS)': 'Electric Power Transmission, Control, and Distribution(22112)',
#   'Long term Debt': 16538242.0,
#   'Net Sales Revenue Trend (%)': 16.06,
#   'Number of Employees': '401 (2024)',
#   'Operating Profit Trend (%)': -70.27,
#   'Property, plant and equipment': 15922277.0,
#   'Return on Assets (ROA) (%)': 0.77,
#   'Return on Equity (ROE) (%)': 1.71,
#   'Quick Ratio (x)': 1.25,
#   'Short Term Debt': 2429575.0,
#   'Total operating revenue': 7988164.0},
#  {'Company': 'Caja de Compensacion Familiar COMPENSAR',
#   'Cash and Cash Equivalents': 457096.09,
#   'Export': ' ',
#   'Import': 'CN (2.92%), BR (2.14%), US (88.1%), PL (6.84%)',
#   'Industry (NAICS)': 'Health and Welfare Funds(52512)',
#   'Long term Debt': 164346.19,
#   'Net Sales Revenue Trend (%)': 18.13,
#   'Number of Employees': '9,172 (2024)',
#   'Operating Profit Trend (%)': -177.84,
#   'Property, plant and equipment': 1793318.66,
#   'Return on Assets (ROA) (%)': 2.54,
#   'Return on Equity (ROE) (%)': 6.72,
#   'Quick Ratio (x)': 1.32,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 7557677.15},
#  {'Company': 'Colombia Telecommunications S.A. E.S.P. (Movistar Colombia)',
#   'Cash and Cash Equivalents': 362205.67,
#   'Export': 'CO (92.62%), PE (7.38%)',
#   'Import': 'Germany, CN (79.19%), TW (0.32%), MY (0.02%), MX (1.4%), VN (8.94%), BR (4.63%), US (0.47%), TH (4.66%), ES (0.37%)',
#   'Industry (NAICS)': 'Wireless Telecommunications Carriers (except Satellite)(517312); Other Telecommunications(51791)',
#   'Long term Debt': 4957301.57,
#   'Net Sales Revenue Trend (%)': -0.98,
#   'Number of Employees': '5,623 (2024)',
#   'Operating Profit Trend (%)': -84.39,
#   'Property, plant and equipment': 3956375.04,
#   'Return on Assets (ROA) (%)': -5.14,
#   'Return on Equity (ROE) (%)': -17.45,
#   'Quick Ratio (x)': 0.59,
#   'Short Term Debt': 1385317.75,
#   'Total operating revenue': 7122914.83},
#  {'Company': 'Cenit Transporte y Logistica de Hidrocarburos S A S',
#   'Cash and Cash Equivalents': 1147503.24,
#   'Export': 'PE (100%)',
#   'Import': 'UK (45.08%), KR (0.06%), US (31.2%), CA (23.6%), CH (0.06%)',
#   'Industry (NAICS)': 'Pipeline Transportation(486)',
#   'Long term Debt': 68050.6,
#   'Net Sales Revenue Trend (%)': 24.09,
#   'Number of Employees': '1,140 (2024)',
#   'Operating Profit Trend (%)': 11.26,
#   'Property, plant and equipment': 11605880.87,
#   'Return on Assets (ROA) (%)': 24.02,
#   'Return on Equity (ROE) (%)': 28.34,
#   'Quick Ratio (x)': 1.78,
#   'Short Term Debt': 246770.89,
#   'Total operating revenue': 7113995.49},
#  {'Company': 'Carbones del Cerrejon Limited',
#   'Cash and Cash Equivalents': 2268.49,
#   'Export': 'IE (3.95%), NL (21.61%), BE (0.34%), TW (0.26%), KR (11.53%), TR (14.87%), JP (0.27%), CA (2.92%), CN (9.83%), DE (3.19%), SI (0.68%), MA (4.54%), PL (1.34%), AR (0.78%), HR (0.39%), IT (2.86%), BR (2.07%), US (0.37%), IL (9.1%), ES (2.42%), DO (1.2%), CL (4.81%), FR (0.67%)',
#   'Import': 'UK (0.47%), NL (0.36%), AT (0.12%), MY (0.01%), Costa Rica, DK (0.1%), Panama, PR (0.01%), JP (15.03%), SE (3.41%), CN (1.78%), Bulgaria, IT (0.72%), CH (0.06%), Vietnam, CZ (0.03%), US (67.53%), PE (0.1%), Sri Lanka, ES (0.23%), FR (0.71%), Indonesia, AU (1.02%), Ireland, GE (0.03%), Tunisia, BE (0.02%), TW (0.13%), Estonia, KR (0.09%), ZA (0.04%), PT (0.01%), TR (0.05%), CA (1.06%), DE (1.84%), FI (0.03%), PK (0.01%), Colombia, Lithuania, Romania, SG (0.01%), PL (0.06%), AR (0.01%), IN (0.52%), MX (3.14%), BR (0.09%), TH (0.01%), Israel, Slovakia, NZ (0.02%), Dominican Republic, CL (1.14%), Hungary',
#   'Industry (NAICS)': 'Coal Mining(21211)',
#   'Long term Debt': 553941.86,
#   'Net Sales Revenue Trend (%)': -54.42,
#   'Number of Employees': '5,501 (2024)',
#   'Operating Profit Trend (%)': -95.04,
#   'Property, plant and equipment': 4392545.89,
#   'Return on Assets (ROA) (%)': 2.79,
#   'Return on Equity (ROE) (%)': 5.2,
#   'Quick Ratio (x)': 1.91,
#   'Short Term Debt': 12910.98,
#   'Total operating revenue': 6976125.26},
#  {'Company': 'Salud Total Entidad Promotora de Salud del Regimen Contributivo y del Regimen Subsidiado S.A.',
#   'Cash and Cash Equivalents': 68744.72,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Other Justice, Public Order, and Safety Activities(92219); Other Ambulatory Health Care Services(6219)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.1,
#   'Number of Employees': '2,000 (2024)',
#   'Operating Profit Trend (%)': -400.51,
#   'Property, plant and equipment': 69972.99,
#   'Return on Assets (ROA) (%)': 3.17,
#   'Return on Equity (ROE) (%)': 28.65,
#   'Quick Ratio (x)': 2.37,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6910340.0},
#  {'Company': 'Caja Colombiana de Subsidio Familiar COLSUBSIDIO',
#   'Cash and Cash Equivalents': 112663.16,
#   'Export': ' ',
#   'Import': 'CN (13.06%), GR (8.96%), EC (12.37%), ES (14.7%), CL (50.91%)',
#   'Industry (NAICS)': 'Health and Welfare Funds(52512)',
#   'Long term Debt': 561067.61,
#   'Net Sales Revenue Trend (%)': 16.88,
#   'Number of Employees': '5,001 - 10,000 (2024)',
#   'Operating Profit Trend (%)': 1.72,
#   'Property, plant and equipment': 1726188.21,
#   'Return on Assets (ROA) (%)': 2.1,
#   'Return on Equity (ROE) (%)': 5.38,
#   'Quick Ratio (x)': 1.04,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6783544.32},
#  {'Company': 'Positiva Compania de Seguros Sa',
#   'Cash and Cash Equivalents': 280306.77,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Direct Life Insurance Carriers(524113)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.9,
#   'Number of Employees': '766 (2024)',
#   'Operating Profit Trend (%)': 43.94,
#   'Property, plant and equipment': 99737.21,
#   'Return on Assets (ROA) (%)': 3.16,
#   'Return on Equity (ROE) (%)': 20.32,
#   'Quick Ratio (x)': 1.07,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6656322.48},
#  {'Company': 'C.I. Trafigura Petroleum Colombia S.A.S.',
#   'Cash and Cash Equivalents': 7878.35,
#   'Export': 'JM (10.19%), IN (4.21%), PA (27.54%), US (38.7%), PE (6.89%), ES (7.83%), CA (4.64%)',
#   'Import': ' ',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472)',
#   'Long term Debt': 3376.08,
#   'Net Sales Revenue Trend (%)': -3.64,
#   'Number of Employees': '4 (2023)',
#   'Operating Profit Trend (%)': -114.09,
#   'Property, plant and equipment': 0.0,
#   'Return on Assets (ROA) (%)': 0.37,
#   'Return on Equity (ROE) (%)': 8.57,
#   'Quick Ratio (x)': 0.76,
#   'Short Term Debt': 537.13,
#   'Total operating revenue': 6334602.41},
#  {'Company': 'Bavaria & Cia S.C.A',
#   'Cash and Cash Equivalents': 608964.04,
#   'Export': 'UK (0.2%), AU (0.02%), EC (20.16%), BB (3.53%), PA (6.17%), VC (1.84%), GT (9.08%), Germany, MU (10.64%), Italy, MX (0.02%), BR (4.69%), HN (4.34%), US (9.21%), PE (25.6%), ES (1.94%), DO (1.04%), CU (0.96%), CL (0.56%)',
#   'Import': 'UK (0.08%), Philippines, NL (0.18%), EC (1.3%), Austria, Malaysia, DK (0.1%), Puerto Rico, JP (0.57%), Sweden, CN (6.46%), Bulgaria, Malta, IT (1.24%), CH (0.07%), Vietnam, CZ (0.16%), US (6.58%), PE (2.62%), ES (0.15%), FR (8.94%), Indonesia, BE (0.27%), Taiwan, China, Estonia, PT (0.04%), Turkiye, CA (2.36%), GT (0.45%), Finland, DE (3.6%), Romania, Singapore, AR (31.5%), India, PL (6.51%), MX (18.53%), BR (7.7%), AE (0.59%), Thailand, Slovakia, Hungary',
#   'Industry (NAICS)': 'Breweries(31212)',
#   'Long term Debt': 75601.53,
#   'Net Sales Revenue Trend (%)': 9.38,
#   'Number of Employees': '2,749 (2024)',
#   'Operating Profit Trend (%)': -9.48,
#   'Property, plant and equipment': 3707545.0,
#   'Return on Assets (ROA) (%)': 17.37,
#   'Return on Equity (ROE) (%)': 76.81,
#   'Quick Ratio (x)': 0.88,
#   'Short Term Debt': 489123.57,
#   'Total operating revenue': 6235011.18},
#  {'Company': 'Oleoducto Central S.A.',
#   'Cash and Cash Equivalents': 1095721.97,
#   'Export': 'UK (100%)',
#   'Import': 'UK (17.29%), BE (0.8%), AT (2.28%), TW (0.15%), KR (4.61%), ZA (0.07%), JP (0.22%), CA (1.19%), CN (0.56%), DE (26.02%), PL (0.11%), CH (5.51%), IN (0.54%), IT (0.6%), MX (7.95%), VN (0.13%), CZ (0.01%), BR (0.05%), AE (0.78%), US (31.08%), Thailand, FR (0.03%), HU (0.02%)',
#   'Industry (NAICS)': 'Pipeline Transportation(486)',
#   'Long term Debt': 1548301.08,
#   'Net Sales Revenue Trend (%)': 11.36,
#   'Number of Employees': '275 (2024)',
#   'Operating Profit Trend (%)': 11.86,
#   'Property, plant and equipment': 4811039.19,
#   'Return on Assets (ROA) (%)': 42.31,
#   'Return on Equity (ROE) (%)': 75.57,
#   'Quick Ratio (x)': 1.82,
#   'Short Term Debt': 104578.68,
#   'Total operating revenue': 6143100.32},
#  {'Company': 'Sodimac Colombia S.A.',
#   'Cash and Cash Equivalents': 346045.27,
#   'Export': 'CN (88.68%), EC (11.32%)',
#   'Import': 'UK (0.1%), PH (0.18%), KH (0.01%), NL (0.06%), EC (0.19%), AT (0.04%), MY (0.57%), DK (0.14%), Panama, JP (0.03%), CN (76.25%), IT (0.08%), Switzerland, VN (0.27%), Czech Republic, US (0.72%), PE (0.94%), Sri Lanka, Sierra Leone, ES (3%), EG (0.39%), ID (0.39%), Australia, BE (0.31%), TW (0.56%), EE (0.03%), KR (0.03%), PT (0.05%), TR (0.26%), CA (0.4%), DE (1.54%), Finland, Slovenia, Pakistan, Colombia, Lithuania, Romania, PL (0.12%), Argentina, IN (0.41%), MX (0.86%), BR (3.49%), TH (0.05%), IL (0.04%), SK (0.24%), CL (8.23%), Hungary, BD (0.02%)',
#   'Industry (NAICS)': 'Miscellaneous Store Retailers(453)',
#   'Long term Debt': 1501006.75,
#   'Net Sales Revenue Trend (%)': -4.06,
#   'Number of Employees': '9,181 (2024)',
#   'Operating Profit Trend (%)': -1.3,
#   'Property, plant and equipment': 2326729.42,
#   'Return on Assets (ROA) (%)': 7.62,
#   'Return on Equity (ROE) (%)': 18.45,
#   'Quick Ratio (x)': 0.79,
#   'Short Term Debt': 64432.56,
#   'Total operating revenue': 5761589.34},
#  {'Company': 'Chevron Petroleum Company',
#   'Cash and Cash Equivalents': 82276.0,
#   'Export': 'NI (1.08%), JM (1.14%), EC (20.76%), CR (1.56%), PA (0.34%), PR (1.8%), GT (3.07%), SV (4.19%), MX (1.41%), HN (5.9%), TT (5.78%), PE (41.25%), US (6.58%), DO (2.29%), CL (2.85%)',
#   'Import': 'UK (0.08%), Indonesia, BE (2.09%), TW (0.01%), JP (0.12%), CA (0.26%), Guatemala, China, DE (0.07%), FI (0.1%), Sweden, Colombia, BH (1.34%), El Salvador, CH (0.01%), BR (2.15%), US (93.57%), TH (0.19%), FR (0.01%)',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472); Natural Gas Extraction(21113); Other Miscellaneous Manufacturing(3399)',
#   'Long term Debt': 3165.0,
#   'Net Sales Revenue Trend (%)': 25.66,
#   'Number of Employees': '189 (2024)',
#   'Operating Profit Trend (%)': -320.9,
#   'Property, plant and equipment': 646002.0,
#   'Return on Assets (ROA) (%)': 0.84,
#   'Return on Equity (ROE) (%)': 15.61,
#   'Quick Ratio (x)': 0.78,
#   'Short Term Debt': 52288.0,
#   'Total operating revenue': 5720906.0},
#  {'Company': 'Verano Energy (Switzerland) Ag Sucursal',
#   'Cash and Cash Equivalents': 128849.35,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Oil and Gas Extraction(2111)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 18.94,
#   'Number of Employees': '49 (2012)',
#   'Operating Profit Trend (%)': -128.66,
#   'Property, plant and equipment': 5145558.99,
#   'Return on Assets (ROA) (%)': 4.19,
#   'Return on Equity (ROE) (%)': 11.86,
#   'Quick Ratio (x)': 3.18,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 5407766.82},
#  {'Company': 'Droguerias y Farmacias Cruz Verde S.A.S',
#   'Cash and Cash Equivalents': 19121.87,
#   'Export': 'NL (41.78%), AT (58.22%)',
#   'Import': 'CN (4.03%), DE (8.82%), UK (1.09%), NL (10.3%), AT (51.21%), IT (0.18%), PL (0.01%), US (13.46%), JP (10.9%), Hungary',
#   'Industry (NAICS)': 'Pharmaceutical Preparation Manufacturing(325412); Pharmacies and Drug Stores(44611)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 20.63,
#   'Number of Employees': '7,743 (2024)',
#   'Operating Profit Trend (%)': -100.45,
#   'Property, plant and equipment': 173459.55,
#   'Return on Assets (ROA) (%)': -1.54,
#   'Return on Equity (ROE) (%)': -8.25,
#   'Quick Ratio (x)': 0.7,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 5127429.73},
#  {'Company': 'Industria Nacional de Gaseosas S.A.',
#   'Cash and Cash Equivalents': 132836.18,
#   'Export': 'DE (25.19%), PA (15.5%), VE (53.73%), PE (0.07%), IT (5.51%)',
#   'Import': 'UK (0.01%), Netherlands, AT (0.06%), CR (0.4%), DK (0.17%), PA (0.01%), Japan, SE (0.01%), CN (1.32%), UY (0.54%), Morocco, MT (0.01%), IT (1.64%), CH (0.01%), Vietnam, CZ (0.04%), US (2.32%), PE (3.69%), ES (0.3%), FR (0.05%), BO (2.48%), Indonesia, Ireland, GE (0.27%), TW (0.02%), South Korea, SA (0.8%), Portugal, TR (0.01%), CA (0.06%), DE (16.75%), Romania, Singapore, AR (4.67%), IN (0.91%), PL (0.03%), MX (8.56%), BR (54.62%), Slovakia, HU (0.07%), CL (0.17%)',
#   'Industry (NAICS)': 'Soft Drink Manufacturing(312111)',
#   'Long term Debt': 230000.0,
#   'Net Sales Revenue Trend (%)': 21.55,
#   'Number of Employees': '1,741 (2024)',
#   'Operating Profit Trend (%)': 38.49,
#   'Property, plant and equipment': 1645822.41,
#   'Return on Assets (ROA) (%)': -1.56,
#   'Return on Equity (ROE) (%)': -5.66,
#   'Quick Ratio (x)': 0.4,
#   'Short Term Debt': 32486.44,
#   'Total operating revenue': 4878634.49},
#  {'Company': 'Frontera Energy Colombia Corp., Sucursal Colombia',
#   'Cash and Cash Equivalents': 101252.47,
#   'Export': 'PA (64.44%), JM (6.68%), US (24.2%), CA (4.68%)',
#   'Import': 'DE (0.18%), CN (0.34%), NL (0.15%), India, Switzerland, US (99.33%), Hungary',
#   'Industry (NAICS)': 'Crude Petroleum Extraction(21112); Direct Selling Establishments(4543)',
#   'Long term Debt': 48007.08,
#   'Net Sales Revenue Trend (%)': -10.56,
#   'Number of Employees': '795 (2024)',
#   'Operating Profit Trend (%)': -50.78,
#   'Property, plant and equipment': 5811742.02,
#   'Return on Assets (ROA) (%)': 7.9,
#   'Return on Equity (ROE) (%)': 10.77,
#   'Quick Ratio (x)': 0.71,
#   'Short Term Debt': 93436.66,
#   'Total operating revenue': 4741579.92},
#  {'Company': 'Grupo Bolivar S.A.',
#   'Cash and Cash Equivalents': 15470750.82,
#   'Export': 'PA (6.36%), HN (86.17%), US (2.09%), CR (0.66%), CL (4.72%)',
#   'Import': ' ',
#   'Industry (NAICS)': 'Insurance and Employee Benefit Funds(5251)',
#   'Long term Debt': 63370605.89,
#   'Net Sales Revenue Trend (%)': -89.23,
#   'Number of Employees': '10 (2024)',
#   'Operating Profit Trend (%)': -163.13,
#   'Property, plant and equipment': 1946516.52,
#   'Return on Assets (ROA) (%)': 0.1,
#   'Return on Equity (ROE) (%)': 1.04,
#   'Quick Ratio (x)': 1.8,
#   'Short Term Debt': 99837325.25,
#   'Total operating revenue': 4637664.28},
#  {'Company': 'Cencosud Colombia S.A.',
#   'Cash and Cash Equivalents': 103018.06,
#   'Export': 'GR (100%)',
#   'Import': 'ID (0.07%), AU (0.07%), HK (0.02%), EC (3.58%), BE (0.26%), AT (0.94%), MY (0.04%), KR (0.06%), DK (0.48%), PT (0.18%), TR (0.21%), CA (0.05%), CN (52.7%), DE (1.67%), GR (0.23%), UY (0.49%), SV (0.11%), IT (3.77%), IN (0.18%), AR (4.07%), MX (1.2%), VN (0.27%), BR (2.73%), US (8.39%), TH (0.06%), ES (7.84%), CL (8.79%), FR (0.53%), BD (1.01%)',
#   'Industry (NAICS)': 'General Merchandise Stores, including Warehouse Clubs and Supercenters(45231); Grocery Stores(4451)',
#   'Long term Debt': 75810.69,
#   'Net Sales Revenue Trend (%)': -4.56,
#   'Number of Employees': '10,277 (2024)',
#   'Operating Profit Trend (%)': -120.0,
#   'Property, plant and equipment': 2080917.79,
#   'Return on Assets (ROA) (%)': -0.08,
#   'Return on Equity (ROE) (%)': -0.12,
#   'Quick Ratio (x)': 0.43,
#   'Short Term Debt': 22795.37,
#   'Total operating revenue': 4429314.08},
#  {'Company': 'Automotores Toyota Colombia S A S',
#   'Cash and Cash Equivalents': 241560.83,
#   'Export': 'AR (100%)',
#   'Import': 'United Kingdom, Philippines, Cambodia, Netherlands, Hong Kong SAR, China, Malaysia, Panama, JP (25.3%), CN (0.02%), Uruguay, Italy, Vietnam, Czech Republic, US (0.12%), Spain, FR (6.64%), ID (0.03%), Australia, Belgium, Taiwan, China, South Korea, South Africa, Turkiye, Canada, Germany, Slovenia, Madagascar, Romania, India, AR (41.45%), Poland, Singapore, Mexico, BR (25.99%), TH (0.45%), Slovakia, Hungary',
#   'Industry (NAICS)': 'New Car Dealers(44111); Motor Vehicle and Motor Vehicle Parts and Supplies Merchant Wholesalers(4231)',
#   'Long term Debt': 135610.23,
#   'Net Sales Revenue Trend (%)': 16.37,
#   'Number of Employees': '181 (2024)',
#   'Operating Profit Trend (%)': 42.0,
#   'Property, plant and equipment': 10201.5,
#   'Return on Assets (ROA) (%)': 26.4,
#   'Return on Equity (ROE) (%)': 82.63,
#   'Quick Ratio (x)': 0.7,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 4163114.54},
#  {'Company': 'La Previsora S A Compania de Seguros',
#   'Cash and Cash Equivalents': 225547.85,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Direct Life Insurance Carriers(524113); Direct Insurance (except Life, Health, and Medical) Carriers(52412)',
#   'Long term Debt': 3285.48,
#   'Net Sales Revenue Trend (%)': 35.96,
#   'Number of Employees': '1,532 (2024)',
#   'Operating Profit Trend (%)': -310.05,
#   'Property, plant and equipment': 57073.07,
#   'Return on Assets (ROA) (%)': 4.33,
#   'Return on Equity (ROE) (%)': 27.24,
#   'Quick Ratio (x)': 4.29,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 3781899.45},
#  {'Company': 'Biomax Biocombustibles S.A.',
#   'Cash and Cash Equivalents': 47398.01,
#   'Export': ' ',
#   'Import': 'CN (1.85%), MX (1.78%), UK (0.06%), US (96.11%), MY (0.2%)',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472)',
#   'Long term Debt': 611591.49,
#   'Net Sales Revenue Trend (%)': 22.11,
#   'Number of Employees': '286 (2024)',
#   'Operating Profit Trend (%)': 47.48,
#   'Property, plant and equipment': 181881.61,
#   'Return on Assets (ROA) (%)': 4.43,
#   'Return on Equity (ROE) (%)': 12.87,
#   'Quick Ratio (x)': 0.44,
#   'Short Term Debt': 99525.9,
#   'Total operating revenue': 3727003.2},
#  {'Company': 'Italcol S.A.',
#   'Cash and Cash Equivalents': 4751.79,
#   'Export': 'AW (4.48%), PA (37.37%), EC (42.89%), DO (15.26%)',
#   'Import': 'ID (0.08%), NL (0.29%), TN (0.06%), EC (0.08%), Belgium, CR (0.13%), KR (0.05%), Portugal, TR (0.05%), JP (0.15%), CN (7.66%), DE (0.07%), BG (0.04%), PY (1.68%), IT (0.23%), AR (3.85%), CH (0.06%), IN (0.11%), BR (13.2%), US (67.92%), ES (0.38%), CL (0.09%), FR (0.45%), Hungary, BO (3.37%)',
#   'Industry (NAICS)': 'Animal Food Manufacturing(31111); Warehousing and Storage(4931); Farm Product Raw Material Merchant Wholesalers(4245)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 6.36,
#   'Number of Employees': '289 (2024)',
#   'Operating Profit Trend (%)': 83.88,
#   'Property, plant and equipment': 260619.77,
#   'Return on Assets (ROA) (%)': 12.86,
#   'Return on Equity (ROE) (%)': 26.03,
#   'Quick Ratio (x)': 0.55,
#   'Short Term Debt': 6274.47,
#   'Total operating revenue': 3654627.67},
#  {'Company': 'Cerrejon Zona Norte S.A.',
#   'Cash and Cash Equivalents': 12705.38,
#   'Export': 'IE (2.74%), NL (14.85%), TW (0.6%), KR (13.59%), TR (17.88%), JP (0.62%), CA (4.29%), CN (5.23%), DE (3.03%), SI (1.57%), MA (7.35%), PL (1.55%), AR (0.43%), HR (0.91%), IT (3.23%), BR (2.15%), IL (10.23%), ES (1.37%), DO (0.51%), CL (6.32%), FR (1.55%)',
#   'Import': ' ',
#   'Industry (NAICS)': 'Coal Mining(21211)',
#   'Long term Debt': 63696.13,
#   'Net Sales Revenue Trend (%)': -50.68,
#   'Number of Employees': '9 (2024)',
#   'Operating Profit Trend (%)': -83.45,
#   'Property, plant and equipment': 3048048.54,
#   'Return on Assets (ROA) (%)': 13.27,
#   'Return on Equity (ROE) (%)': 16.89,
#   'Quick Ratio (x)': 14.95,
#   'Short Term Debt': 23047.92,
#   'Total operating revenue': 3632510.26},
#  {'Company': 'Fondo Nacional del Cafe',
#   'Cash and Cash Equivalents': 310982.88,
#   'Export': 'UK (3.36%), IS (0.03%), NL (0.32%), HK (0.06%), EC (1.75%), MY (0.07%), CR (0.02%), DK (0.17%), JP (15.58%), SE (1.17%), CN (1.37%), IT (1.33%), CH (0.01%), DZ (0.01%), US (26.58%), PE (0.43%), ES (2.22%), BZ (0.01%), FR (0.9%), EG (0.01%), AU (0.2%), BE (9.01%), TW (0.87%), EE (0.01%), LV (0.04%), SA (0.01%), RU (2.11%), KR (3.01%), NO (2.26%), PT (0.37%), TR (0.02%), CA (7.51%), DE (6.85%), FI (2.53%), GR (0.01%), SI (0.28%), LT (0.01%), RO (0.58%), PL (1.81%), AR (0.08%), MX (5.39%), UA (0.01%), IL (0.29%), NZ (0.12%), DO (0.03%), CL (1.18%)',
#   'Import': 'UK (0.02%), AU (37.23%), NL (0.36%), KP (0.02%), RU (0.84%), JP (2.2%), CN (0.09%), DE (22.49%), CO (1.92%), AR (0.05%), IN (0.04%), IT (0.64%), BR (30.49%), VN (1.11%), US (2.5%)',
#   'Industry (NAICS)': 'Coffee and Tea Manufacturing(31192)',
#   'Long term Debt': 198746.6,
#   'Net Sales Revenue Trend (%)': -11.14,
#   'Number of Employees': '3,071 (2019)',
#   'Operating Profit Trend (%)': -104.04,
#   'Property, plant and equipment': 893706.89,
#   'Return on Assets (ROA) (%)': -5.17,
#   'Return on Equity (ROE) (%)': -16.89,
#   'Quick Ratio (x)': 0.39,
#   'Short Term Debt': 1563029.03,
#   'Total operating revenue': 3324858.52},
#  {'Company': 'Caja de Compensacion Familiar CAFAM',
#   'Cash and Cash Equivalents': 99677.32,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Health and Welfare Funds(52512)',
#   'Long term Debt': 352170.32,
#   'Net Sales Revenue Trend (%)': 15.18,
#   'Number of Employees': '10,088 (2017)',
#   'Operating Profit Trend (%)': -975.78,
#   'Property, plant and equipment': 2714672.48,
#   'Return on Assets (ROA) (%)': 1.27,
#   'Return on Equity (ROE) (%)': 2.81,
#   'Quick Ratio (x)': 0.74,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 3209832.33},
#  {'Company': 'Samsung Electronics Colombia S A',
#   'Cash and Cash Equivalents': 65559.25,
#   'Export': 'UK (1.51%), DE (1.93%), NL (0.52%), MX (2.11%), KR (4.1%), BR (1.45%), HN (0.32%), PA (0.14%), US (46.49%), PE (37.19%), CL (4.24%)',
#   'Import': 'United Kingdom, ID (0.01%), Philippines, HK (0.01%), Taiwan, China, MY (0.28%), KR (1.14%), Panama, Turkiye, JP (0.01%), CN (11.08%), Germany, Singapore, IN (0.67%), Poland, MX (33.28%), VN (51.9%), Honduras, Ivory Coast, United States, TH (1.62%), Slovakia, Hungary, Bangladesh',
#   'Industry (NAICS)': 'Household Appliances, Electric Housewares, and Consumer Electronics Merchant Wholesalers(42362)',
#   'Long term Debt': 3572.76,
#   'Net Sales Revenue Trend (%)': -28.02,
#   'Number of Employees': '181 (2024)',
#   'Operating Profit Trend (%)': -34.89,
#   'Property, plant and equipment': 3923.05,
#   'Return on Assets (ROA) (%)': 2.44,
#   'Return on Equity (ROE) (%)': 11.94,
#   'Quick Ratio (x)': 1.06,
#   'Short Term Debt': 2785.5,
#   'Total operating revenue': 3126845.17},
#  {'Company': 'Geopark Colombia Sas',
#   'Cash and Cash Equivalents': 414209.01,
#   'Export': 'PA (20.2%), US (61.59%), EE (1.72%), CL (16.49%)',
#   'Import': 'China, Mexico, United States, Canada',
#   'Industry (NAICS)': 'Crude Petroleum Extraction(21112)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -27.67,
#   'Number of Employees': '487 (2024)',
#   'Operating Profit Trend (%)': -35.62,
#   'Property, plant and equipment': 2359569.61,
#   'Return on Assets (ROA) (%)': 20.74,
#   'Return on Equity (ROE) (%)': 35.42,
#   'Quick Ratio (x)': 1.07,
#   'Short Term Debt': 268.86,
#   'Total operating revenue': 3030629.55},
#  {'Company': 'Parex Resources (Colombia) Ag Sucursal',
#   'Cash and Cash Equivalents': 204598.19,
#   'Export': 'PA (37.21%), US (62.67%), CA (0.12%)',
#   'Import': 'DE (0.11%), CN (0.02%), United Kingdom, AU (0.87%), Malaysia, AR (0.65%), IT (0.04%), SG (0.01%), SA (31.05%), BR (5.54%), US (2.44%), ES (20.2%), FR (0.2%), JP (38.87%)',
#   'Industry (NAICS)': 'Crude Petroleum Extraction(21112)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -50.45,
#   'Number of Employees': '374 (2024)',
#   'Operating Profit Trend (%)': -64.89,
#   'Property, plant and equipment': 2345038.11,
#   'Return on Assets (ROA) (%)': 13.02,
#   'Return on Equity (ROE) (%)': 35.19,
#   'Quick Ratio (x)': 0.36,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2832154.48},
#  {'Company': 'U.A.E. de la Aeronautica Civil',
#   'Cash and Cash Equivalents': 91615.02,
#   'Export': 'US (100%)',
#   'Import': 'CN (0.89%), SE (0.45%), AT (96.29%), US (0.48%), FR (1.89%)',
#   'Industry (NAICS)': 'Support Activities for Air Transportation(4881)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.38,
#   'Number of Employees': '101 - 500 (2024)',
#   'Operating Profit Trend (%)': 20.04,
#   'Property, plant and equipment': 840497.92,
#   'Return on Assets (ROA) (%)': 7.18,
#   'Return on Equity (ROE) (%)': 8.1,
#   'Quick Ratio (x)': 7.87,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2776200.2},
#  {'Company': 'Terpel Exportaciones C.I S.A.S',
#   'Cash and Cash Equivalents': 42106.52,
#   'Export': 'UK (2.56%), Nicaragua, JM (0.01%), Barbados, EC (3.58%), CR (1.74%), Haiti, PA (4.35%), Saint Vincent and the Grenadines, Dominica, PR (0.47%), UY (0.63%), SV (0.94%), PY (0.34%), BS (0.02%), CH (0.04%), Turks and Caicos Islands, PE (4.22%), US (26.73%), ES (24.05%), Belize, FR (2.75%), CW (0.56%), BO (1.16%), Australia, Belgium, Tunisia, Portugal, CA (2.48%), GT (0.39%), DE (0.05%), Finland, Antigua and Barbuda, Bermuda, Madagascar, VE (0.25%), Anguilla, AR (1.74%), MX (7.31%), AW (0.77%), HN (0.04%), BR (2.8%), Trinidad and Tobago, CL (5.84%), CU (0.48%), DO (3.7%), Saint Kitts and Nevis',
#   'Import': ' ',
#   'Industry (NAICS)': 'Gasoline Stations(4471)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 18.82,
#   'Number of Employees': '3 (2024)',
#   'Operating Profit Trend (%)': -59.46,
#   'Property, plant and equipment': 0.0,
#   'Return on Assets (ROA) (%)': 0.53,
#   'Return on Equity (ROE) (%)': 3.38,
#   'Quick Ratio (x)': 0.63,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2701469.3},
#  {'Company': 'Colombia Movil S A E S P',
#   'Cash and Cash Equivalents': 23302.54,
#   'Export': 'CO (100%)',
#   'Import': 'MX (2.18%), CN (96.79%), TW (0.51%), MY (0.03%), HU (0.49%)',
#   'Industry (NAICS)': 'Wireless Telecommunications Carriers (except Satellite)(517312); Satellite Telecommunications(5174)',
#   'Long term Debt': 572718.57,
#   'Net Sales Revenue Trend (%)': -0.05,
#   'Number of Employees': '2,397 (2024)',
#   'Operating Profit Trend (%)': 110.54,
#   'Property, plant and equipment': 1354989.6,
#   'Return on Assets (ROA) (%)': -3.65,
#   'Return on Equity (ROE) (%)': -407.16,
#   'Quick Ratio (x)': 0.37,
#   'Short Term Debt': 385762.36,
#   'Total operating revenue': 2695937.15},
#  {'Company': 'Hocol S.A.',
#   'Cash and Cash Equivalents': 80904.34,
#   'Export': 'US (100%)',
#   'Import': 'CN (1.11%), UK (9.02%), MY (0.02%), TW (0.02%), RO (0.01%), MX (0.43%), US (87.79%), NZ (1.52%), JP (0.08%)',
#   'Industry (NAICS)': 'Natural Gas Extraction(21113); Crude Petroleum Extraction(21112)',
#   'Long term Debt': 70708.48,
#   'Net Sales Revenue Trend (%)': -14.52,
#   'Number of Employees': '415 (2024)',
#   'Operating Profit Trend (%)': -97.17,
#   'Property, plant and equipment': 889190.09,
#   'Return on Assets (ROA) (%)': 5.73,
#   'Return on Equity (ROE) (%)': 9.44,
#   'Quick Ratio (x)': 0.77,
#   'Short Term Debt': 96126.64,
#   'Total operating revenue': 2683049.9},
#  {'Company': 'Diana Corporacion S.A.S',
#   'Cash and Cash Equivalents': 7334.57,
#   'Export': ' ',
#   'Import': 'DE (0.04%), CN (0.01%), IT (1.71%), IN (1.07%), AR (14.67%), DK (0.08%), BR (8.78%), TH (0.84%), PE (14.55%), US (7.46%), ES (0.13%), TR (0.83%), CA (48.8%), BO (1.03%)',
#   'Industry (NAICS)': 'Grocery and Related Product Merchant Wholesalers(4244); Grain and Oilseed Milling(3112)',
#   'Long term Debt': 133202.76,
#   'Net Sales Revenue Trend (%)': 6.93,
#   'Number of Employees': '1,731 (2024)',
#   'Operating Profit Trend (%)': 10.32,
#   'Property, plant and equipment': 537863.05,
#   'Return on Assets (ROA) (%)': -0.82,
#   'Return on Equity (ROE) (%)': -3.55,
#   'Quick Ratio (x)': 0.35,
#   'Short Term Debt': 634941.05,
#   'Total operating revenue': 2603130.87},
#  {'Company': 'Teixeira Duarte - Engenharia E Construcoes, Sucursal en Colombia',
#   'Cash and Cash Equivalents': 146966.4,
#   'Export': ' ',
#   'Import': 'DE (1.95%), UK (0.45%), IT (82.16%), BR (0.09%), US (0.21%), PT (14.89%), ES (0.12%), FR (0.13%)',
#   'Industry (NAICS)': 'Highway, Street, and Bridge Construction(2373)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 107.33,
#   'Number of Employees': '120 (2024)',
#   'Operating Profit Trend (%)': -333.59,
#   'Property, plant and equipment': 374548.2,
#   'Return on Assets (ROA) (%)': -17.39,
#   'Return on Equity (ROE) (%)': 156.29,
#   'Quick Ratio (x)': 1.21,
#   'Short Term Debt': 583775.3,
#   'Total operating revenue': 2573619.3},
#  {'Company': 'General Motors - Colmotores S.A.',
#   'Cash and Cash Equivalents': 93336.15,
#   'Export': 'Uruguay, VE (5.59%), EC (67.6%), AR (26.59%), PE (0.02%), US (0.17%), CL (0.03%)',
#   'Import': 'United Kingdom, Philippines, Nicaragua, Hong Kong SAR, China, EC (0.04%), Austria, MY (0.01%), JP (3.24%), Sweden, CN (10.17%), Macau SAR, China, Malta, Italy, VN (0.04%), Czech Republic, US (12.55%), PE (0.01%), Sierra Leone, Spain, France, ID (0.06%), Australia, Ireland, Tunisia, Belgium, Taiwan, China, KR (0.78%), South Africa, Portugal, Malawi, Turkiye, CA (0.03%), DE (0.03%), CO (19.21%), Luxembourg, Romania, Singapore, PL (0.01%), AR (15.63%), IN (0.1%), MX (10.43%), BR (27.32%), Honduras, TH (0.27%), Slovakia, CL (0.06%), HU (0.01%), Bangladesh',
#   'Industry (NAICS)': 'New Car Dealers(44111); Motor Vehicle Body and Trailer Manufacturing(33621); Motor Vehicle and Motor Vehicle Parts and Supplies Merchant Wholesalers(4231); Motor Vehicle Manufacturing(3361)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -27.56,
#   'Number of Employees': '602 (2024)',
#   'Operating Profit Trend (%)': -199.1,
#   'Property, plant and equipment': 543694.76,
#   'Return on Assets (ROA) (%)': -10.01,
#   'Return on Equity (ROE) (%)': -36.73,
#   'Quick Ratio (x)': 0.2,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2564116.8},
#  {'Company': 'Teleperformance Colombia S A S',
#   'Cash and Cash Equivalents': 53260.58,
#   'Export': 'GY (82.64%), PT (17.36%)',
#   'Import': 'CN (21.98%), AT (0.4%), TW (65.15%), HT (0.01%), HN (0.02%), US (8.79%), TH (3.57%), BD (0.08%)',
#   'Industry (NAICS)': 'Wired Telecommunications Carriers(517311); Business Support Services(5614); Data Processing, Hosting, and Related Services(518)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 1.94,
#   'Number of Employees': '21,927 (2024)',
#   'Operating Profit Trend (%)': -25.6,
#   'Property, plant and equipment': 146692.36,
#   'Return on Assets (ROA) (%)': 7.7,
#   'Return on Equity (ROE) (%)': 12.45,
#   'Quick Ratio (x)': 2.38,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2555695.43},
#  {'Company': 'Apple Colombia Sas',
#   'Cash and Cash Equivalents': 96048.6,
#   'Export': 'US (100%)',
#   'Import': 'Philippines, Australia, Malaysia, Costa Rica, KR (0.01%), CN (93.58%), Germany, Pitcairn Island, Switzerland, IN (3.18%), MX (0.11%), Czech Republic, VN (2.99%), TH (0.08%), US (0.05%)',
#   'Industry (NAICS)': 'Household Appliances and Electrical and Electronic Goods Merchant Wholesalers(4236)',
#   'Long term Debt': 3794.78,
#   'Net Sales Revenue Trend (%)': 12.83,
#   'Number of Employees': '50 (2024)',
#   'Operating Profit Trend (%)': 96.54,
#   'Property, plant and equipment': 19632.54,
#   'Return on Assets (ROA) (%)': 19.31,
#   'Return on Equity (ROE) (%)': 88.15,
#   'Quick Ratio (x)': 1.22,
#   'Short Term Debt': 1363.77,
#   'Total operating revenue': 2365711.1},
#  {'Company': 'Cerro Matoso S A',
#   'Cash and Cash Equivalents': 150707.0,
#   'Export': 'UK (2.08%), NL (13.99%), HK (0.2%), BE (1.74%), TW (1.11%), KR (6.7%), JP (6.22%), CN (48.04%), FI (4.4%), SE (0.13%), SI (0.82%), IN (2.35%), IT (6.34%), SG (0.62%), US (2.77%), TH (0.13%), ES (2.36%)',
#   'Import': 'UK (0.03%), AT (0.77%), DK (0.27%), Japan, SE (0.9%), CN (4.43%), BG (0.01%), IT (10.92%), CZ (0.02%), CI (0.01%), US (20.56%), PE (0.03%), LK (0.01%), ES (4%), FR (0.52%), AU (3.85%), Georgia, BE (0.13%), TW (0.11%), NO (0.37%), ZA (0.01%), CA (0.21%), FI (0.01%), DE (5.73%), LU (0.11%), SI (0.02%), Romania, AR (0.25%), IN (0.54%), PL (0.04%), MX (2.15%), BR (42.32%), Dominican Republic, BD (1.67%)',
#   'Industry (NAICS)': 'Copper, Nickel, Lead, and Zinc Mining(21223)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -40.67,
#   'Number of Employees': '964 (2024)',
#   'Operating Profit Trend (%)': -89.46,
#   'Property, plant and equipment': 1139411.0,
#   'Return on Assets (ROA) (%)': 8.82,
#   'Return on Equity (ROE) (%)': 20.12,
#   'Quick Ratio (x)': 1.63,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2322628.0},
#  {'Company': 'Compania de Medicina Prepagada Colsanitas S A',
#   'Cash and Cash Equivalents': 594510.0,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Other Ambulatory Health Care Services(6219)',
#   'Long term Debt': 13585.37,
#   'Net Sales Revenue Trend (%)': 15.85,
#   'Number of Employees': '2,241 (2023)',
#   'Operating Profit Trend (%)': 35.96,
#   'Property, plant and equipment': 41472.15,
#   'Return on Assets (ROA) (%)': -0.11,
#   'Return on Equity (ROE) (%)': -0.25,
#   'Quick Ratio (x)': 1.51,
#   'Short Term Debt': 488681.0,
#   'Total operating revenue': 2301000.0},
#  {'Company': 'Falabella de Colombia S A',
#   'Cash and Cash Equivalents': 79684.29,
#   'Export': 'PE (66.11%), CL (33.89%)',
#   'Import': 'Ethiopia, PH (0.12%), KH (0.9%), Nicaragua, HK (0.01%), MY (0.11%), Panama, MM (0.03%), JP (0.53%), CN (79.59%), Macau SAR, China, Bulgaria, MA (0.13%), KE (0.05%), IT (0.15%), VN (4.27%), Czech Republic, US (0.68%), PE (0.4%), LK (0.18%), ES (0.33%), Egypt, FR (0.26%), ID (1.39%), Albania, GE (0.02%), TN (0.01%), TW (0.04%), EE (0.01%), KR (0.01%), South Africa, PT (0.3%), TR (0.39%), CA (0.01%), GT (0.01%), FI (0.08%), DE (0.23%), PK (0.17%), Romania, PL (0.06%), IN (1.98%), MX (1.88%), Central African Republic, JO (0.02%), BR (1.12%), TH (0.25%), SK (0.02%), CL (0.02%), HU (0.08%), BD (4.16%)',
#   'Industry (NAICS)': 'General Merchandise Stores, including Warehouse Clubs and Supercenters(45231)',
#   'Long term Debt': 205842.38,
#   'Net Sales Revenue Trend (%)': -11.17,
#   'Number of Employees': '3,522 (2024)',
#   'Operating Profit Trend (%)': 141.46,
#   'Property, plant and equipment': 352074.97,
#   'Return on Assets (ROA) (%)': -1.56,
#   'Return on Equity (ROE) (%)': -6.49,
#   'Quick Ratio (x)': 0.27,
#   'Short Term Debt': 31805.7,
#   'Total operating revenue': 2241089.43},
#  {'Company': 'Avsa S.A',
#   'Cash and Cash Equivalents': 5558.71,
#   'Export': 'VN (67.5%), HK (32.5%)',
#   'Import': 'United Kingdom, ID (0.01%), NL (3.99%), BE (1.68%), AT (0.05%), Taiwan, China, Malaysia, South Korea, DK (0.03%), JP (0.06%), CA (0.43%), CN (3.81%), DE (1.43%), Bulgaria, Singapore, IT (0.6%), India, AR (0.53%), CH (0.02%), MX (0.07%), BR (18.44%), US (68.38%), Israel, ES (0.01%), FR (0.24%), Hungary, BO (0.22%)',
#   'Industry (NAICS)': 'Meat Markets(44521); Poultry and Egg Production(1123)',
#   'Long term Debt': 13087.46,
#   'Net Sales Revenue Trend (%)': 5.67,
#   'Number of Employees': '5,559 (2024)',
#   'Operating Profit Trend (%)': -50.64,
#   'Property, plant and equipment': 542419.99,
#   'Return on Assets (ROA) (%)': 6.98,
#   'Return on Equity (ROE) (%)': 11.75,
#   'Quick Ratio (x)': 0.45,
#   'Short Term Debt': 157069.57,
#   'Total operating revenue': 2203635.37},
#  {'Company': 'Universidad Nacional de Colombia',
#   'Cash and Cash Equivalents': 1350290.04,
#   'Export': 'US (100%)',
#   'Import': 'UK (0.67%), ID (0.02%), CN (0.6%), BG (0.23%), PK (0.75%), NL (3.67%), India, RU (2.2%), KR (0.04%), DK (0.22%), US (48.54%), ES (0.73%), JP (0.39%), CA (41.94%)',
#   'Industry (NAICS)': 'Educational Services(611)',
#   'Long term Debt': 56000.0,
#   'Net Sales Revenue Trend (%)': 13.84,
#   'Number of Employees': '5,001 - 10,000 (2024)',
#   'Operating Profit Trend (%)': 381.35,
#   'Property, plant and equipment': 3746475.24,
#   'Return on Assets (ROA) (%)': 5.47,
#   'Return on Equity (ROE) (%)': 11.57,
#   'Quick Ratio (x)': 3.3,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2168262.87},
#  {'Company': 'Nestle de Colombia S.A.',
#   'Cash and Cash Equivalents': 31422.96,
#   'Export': 'JM (1%), HK (0.44%), EC (3.57%), BB (0.09%), MY (0.45%), CR (0.52%), ZA (1.52%), PA (0.79%), PR (0.86%), JP (0.97%), CA (3.44%), DE (0.56%), GY (0.09%), VE (2.65%), MU (0.37%), SG (0.51%), MX (1.72%), AW (0.96%), TT (2.43%), US (41.7%), PE (28.57%), IL (1.31%), ES (0.62%), CW (1.61%), Cuba, CL (0.98%), BO (2.27%)',
#   'Import': 'UK (0.93%), PH (0.49%), NL (0.89%), EC (4.76%), Austria, Japan, SE (0.21%), CN (3.9%), Bulgaria, IT (1.97%), CH (3.28%), CZ (0.02%), US (24.17%), PE (0.03%), ES (2.08%), EG (0.17%), FR (1.15%), Ireland, AL (0.01%), TN (0.05%), Taiwan, China, LV (0.05%), NO (0.1%), PT (0.03%), Turkiye, GT (0.4%), DE (3.87%), Colombia, Romania, SG (5.98%), AR (0.43%), IN (0.08%), PL (0.15%), MX (24.5%), BR (8.87%), UA (0.47%), DO (0.14%), CL (9.9%), HU (0.82%), NZ (0.1%)',
#   'Industry (NAICS)': 'Soft Drink Manufacturing(312111); All Other Miscellaneous Food Manufacturing(311999); Coffee and Tea Manufacturing(31192); Dairy Product Manufacturing(3115)',
#   'Long term Debt': 24682.35,
#   'Net Sales Revenue Trend (%)': -0.74,
#   'Number of Employees': '2,528 (2024)',
#   'Operating Profit Trend (%)': -35.44,
#   'Property, plant and equipment': 317442.83,
#   'Return on Assets (ROA) (%)': 3.5,
#   'Return on Equity (ROE) (%)': 64.97,
#   'Quick Ratio (x)': 0.46,
#   'Short Term Debt': 802405.33,
#   'Total operating revenue': 2065475.18},
#  {'Company': 'Pricesmart Colombia S A S',
#   'Cash and Cash Equivalents': 50423.92,
#   'Export': 'SV (23.07%), CR (14.9%), AW (14.13%), TT (11.67%), HN (4.91%), PA (13.38%), DO (2.91%), GT (15.03%)',
#   'Import': 'UK (0.05%), PH (0.08%), KH (0.36%), NL (0.06%), EC (0.01%), MY (0.11%), Eswatini, CR (1.7%), DK (0.16%), JP (0.05%), SE (0.03%), CN (17.11%), SV (0.47%), KE (0.01%), IT (0.39%), CH (0.01%), Oman, VN (0.66%), US (65.15%), PE (0.48%), LK (0.04%), ES (4.49%), EG (0.12%), France, ID (0.06%), BE (0.52%), TW (0.42%), Latvia, KR (0.04%), TR (0.11%), CA (0.83%), GT (0.06%), GR (0.33%), DE (0.18%), PK (0.23%), Singapore, IN (0.91%), MX (2.35%), JO (0.01%), BR (0.34%), HN (0.02%), TH (0.14%), IL (0.01%), Slovakia, Dominican Republic, CL (1.5%), BD (0.4%)',
# ...
#   'Long term Debt': 9280.31,
#   'Net Sales Revenue Trend (%)': 1.41,
#   'Number of Employees': '213 (2024)',
#   'Operating Profit Trend (%)': 7.66,
#   'Property, plant and equipment': 25919.38,
#   'Return on Assets (ROA) (%)': 3.72,
#   'Return on Equity (ROE) (%)': 11.55,
#   'Quick Ratio (x)': 0.5,
#   'Short Term Debt': 46377.52,
#   'Total operating revenue': 104448.32},
#  {'Company': 'Urbanizadora Lindaraja S A S',
#   'Cash and Cash Equivalents': 6961.9,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Residential Building Construction(23611)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 73.18,
#   'Number of Employees': '18 (2024)',
#   'Operating Profit Trend (%)': 150.32,
#   'Property, plant and equipment': 8.8,
#   'Return on Assets (ROA) (%)': -0.1,
#   'Return on Equity (ROE) (%)': -7.39,
#   'Quick Ratio (x)': 1.37,
#   'Short Term Debt': 3000.0,
#   'Total operating revenue': 104408.72},
#  {'Company': 'Funtrition Sas',
#   'Cash and Cash Equivalents': 1618.63,
#   'Export': 'RU (96.78%), US (3.22%)',
#   'Import': 'UK (0.08%), AU (0.32%), NL (3.07%), TR (0.42%), CA (0.16%), CN (0.79%), DE (3.06%), IN (20.81%), CH (4.1%), IT (1.76%), PL (0.1%), MX (0.17%), BR (3.49%), VN (2.94%), US (53.76%), IL (0.95%), PE (0.07%), TH (1.15%), Spain, FR (2.8%)',
#   'Industry (NAICS)': 'All Other Miscellaneous Food Manufacturing(311999)',
#   'Long term Debt': 1644.6,
#   'Net Sales Revenue Trend (%)': 9.34,
#   'Number of Employees': '248 (2024)',
#   'Operating Profit Trend (%)': -66.23,
#   'Property, plant and equipment': 16662.93,
#   'Return on Assets (ROA) (%)': 0.19,
#   'Return on Equity (ROE) (%)': 0.74,
#   'Quick Ratio (x)': 0.77,
#   'Short Term Debt': 10164.34,
#   'Total operating revenue': 104350.62},
#  {'Company': 'Mota - Engil Colombia Sas',
#   'Cash and Cash Equivalents': 3053.12,
#   'Export': ' ',
#   'Import': 'CN (97.33%), AW (0.01%), SI (0.02%), ES (2.26%), IT (0.38%)',
#   'Industry (NAICS)': 'Highway, Street, and Bridge Construction(2373)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -33.51,
#   'Number of Employees': '212 (2024)',
#   'Operating Profit Trend (%)': -539.91,
#   'Property, plant and equipment': 7588.26,
#   'Return on Assets (ROA) (%)': 3.28,
#   'Return on Equity (ROE) (%)': 9.13,
#   'Quick Ratio (x)': 2.14,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 104070.55},
#  {'Company': 'Ferrelugue S A S',
#   'Cash and Cash Equivalents': 2652.85,
#   'Export': ' ',
#   'Import': 'CN (77.57%), BH (4.78%), TR (13.2%), JP (4.45%)',
#   'Industry (NAICS)': 'Lumber and Other Construction Materials Merchant Wholesalers(4233)',
#   'Long term Debt': 9906.1,
#   'Net Sales Revenue Trend (%)': 0.73,
#   'Number of Employees': '141 (2024)',
#   'Operating Profit Trend (%)': -58.36,
#   'Property, plant and equipment': 21412.82,
#   'Return on Assets (ROA) (%)': 0.94,
#   'Return on Equity (ROE) (%)': 2.22,
#   'Quick Ratio (x)': 0.78,
#   'Short Term Debt': 8572.07,
#   'Total operating revenue': 104024.13},
#  {'Company': 'Andean Tower Partners Colombia S A S',
#   'Cash and Cash Equivalents': 3420.31,
#   'Export': ' ',
#   'Import': 'CN (100%)',
#   'Industry (NAICS)': 'Wireless Telecommunications Carriers (except Satellite)(517312)',
#   'Long term Debt': 573592.86,
#   'Net Sales Revenue Trend (%)': 30.37,
#   'Number of Employees': '57 (2024)',
#   'Operating Profit Trend (%)': 110.95,
#   'Property, plant and equipment': 400938.74,
#   'Return on Assets (ROA) (%)': -1.53,
#   'Return on Equity (ROE) (%)': -10.3,
#   'Quick Ratio (x)': 2.41,
#   'Short Term Debt': 8137.92,
#   'Total operating revenue': 103855.64},
#  {'Company': 'Husqvarna Colombia S A',
#   'Cash and Cash Equivalents': 11912.98,
#   'Export': 'PE (64.43%), EC (35.57%)',
#   'Import': 'UK (0.07%), Netherlands, DK (0.02%), JP (1.53%), SE (7.91%), CN (14.41%), BG (0.61%), IT (0.07%), Switzerland, Vietnam, CZ (0.12%), US (4.12%), Spain, France, ID (0.05%), Australia, BE (14.72%), TW (0.27%), EE (0.02%), NO (0.04%), PT (0.02%), Turkiye, CA (2.87%), DE (0.7%), PK (0.01%), Slovenia, LT (0.01%), IN (0.69%), PL (1.4%), Mexico, BR (50.19%), Bosnia and Herzegovina, TH (0.13%), Somalia, Slovakia, Chile, HU (0.02%), Bangladesh',
#   'Industry (NAICS)': 'Industrial Machinery and Equipment Merchant Wholesalers(42383)',
#   'Long term Debt': 670.13,
#   'Net Sales Revenue Trend (%)': -4.09,
#   'Number of Employees': '43 (2024)',
#   'Operating Profit Trend (%)': -16.39,
#   'Property, plant and equipment': 508.47,
#   'Return on Assets (ROA) (%)': 5.08,
#   'Return on Equity (ROE) (%)': 16.85,
#   'Quick Ratio (x)': 0.76,
#   'Short Term Debt': 6246.82,
#   'Total operating revenue': 103843.49},
#  {'Company': 'Ingetec Ingenieria & Diseno Sas',
#   'Cash and Cash Equivalents': 1032.14,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Engineering Services(54133)',
#   'Long term Debt': 231.96,
#   'Net Sales Revenue Trend (%)': 8.32,
#   'Number of Employees': '543 (2024)',
#   'Operating Profit Trend (%)': -37.95,
#   'Property, plant and equipment': 16391.99,
#   'Return on Assets (ROA) (%)': 14.52,
#   'Return on Equity (ROE) (%)': 34.93,
#   'Quick Ratio (x)': 1.18,
#   'Short Term Debt': 7544.42,
#   'Total operating revenue': 103813.47},
#  {'Company': 'Milenio Pc S.A.',
#   'Cash and Cash Equivalents': 10815.42,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Commercial and Industrial Machinery and Equipment Rental and Leasing(5324)',
#   'Long term Debt': 293.75,
#   'Net Sales Revenue Trend (%)': 3.11,
#   'Number of Employees': '162 (2024)',
#   'Operating Profit Trend (%)': -11.99,
#   'Property, plant and equipment': 90674.39,
#   'Return on Assets (ROA) (%)': 21.37,
#   'Return on Equity (ROE) (%)': 25.47,
#   'Quick Ratio (x)': 1.65,
#   'Short Term Debt': 643.33,
#   'Total operating revenue': 103779.29},
#  {'Company': 'Logicalis Colombia S A S',
#   'Cash and Cash Equivalents': 7164.02,
#   'Export': 'US (100%)',
#   'Import': 'Germany, CN (19.1%), PH (0.02%), TW (2.17%), MY (4.4%), PL (0.81%), MX (63.32%), VN (0.04%), US (10.1%), TH (0.04%)',
#   'Industry (NAICS)': 'Household Appliances, Electric Housewares, and Consumer Electronics Merchant Wholesalers(42362)',
#   'Long term Debt': 2655.71,
#   'Net Sales Revenue Trend (%)': 26.67,
#   'Number of Employees': '89 (2024)',
#   'Operating Profit Trend (%)': 439.65,
#   'Property, plant and equipment': 291.42,
#   'Return on Assets (ROA) (%)': 10.84,
#   'Return on Equity (ROE) (%)': 75.21,
#   'Quick Ratio (x)': 1.04,
#   'Short Term Debt': 8055.73,
#   'Total operating revenue': 103446.58},
#  {'Company': 'Imagiq S A S',
#   'Cash and Cash Equivalents': 3277.06,
#   'Export': ' ',
#   'Import': 'KR (100%)',
#   'Industry (NAICS)': 'Machinery, Equipment, and Supplies Merchant Wholesalers(4238)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -37.79,
#   'Number of Employees': '99 (2024)',
#   'Operating Profit Trend (%)': -50.19,
#   'Property, plant and equipment': 8727.43,
#   'Return on Assets (ROA) (%)': 5.55,
#   'Return on Equity (ROE) (%)': 9.42,
#   'Quick Ratio (x)': 1.27,
#   'Short Term Debt': 980.78,
#   'Total operating revenue': 103156.07},
#  {'Company': 'Pear Solutions S.A.S.',
#   'Cash and Cash Equivalents': 10903.92,
#   'Export': ' ',
#   'Import': 'CN (6.69%), CO (93.31%)',
#   'Industry (NAICS)': 'Computer Systems Design and Related Services(54151)',
#   'Long term Debt': 12863.19,
#   'Net Sales Revenue Trend (%)': -5.91,
#   'Number of Employees': '988 (2024)',
#   'Operating Profit Trend (%)': -9.74,
#   'Property, plant and equipment': 11616.53,
#   'Return on Assets (ROA) (%)': 1.62,
#   'Return on Equity (ROE) (%)': 3.37,
#   'Quick Ratio (x)': 2.02,
#   'Short Term Debt': 4238.74,
#   'Total operating revenue': 103149.43},
#  {'Company': 'Filmtex S A S',
#   'Cash and Cash Equivalents': 53.7,
#   'Export': 'EC (13.29%), CR (4.85%), PA (0.23%), GT (0.43%), UY (0.15%), VE (5.32%), SV (0.54%), AR (27.52%), IT (0.12%), MX (9.88%), HN (1.3%), BR (3%), PE (8.67%), US (13.21%), CL (11.34%), BO (0.15%)',
#   'Import': 'KR (11.64%), PA (3.51%), Japan, CN (1.58%), DE (14.73%), SE (0.08%), SI (2.79%), RO (0.4%), AR (6.41%), CH (0.71%), IN (3.45%), IT (3.98%), VN (5.39%), BR (19.78%), US (22.75%), ES (0.49%), FR (0.06%), BO (2.25%)',
#   'Industry (NAICS)': 'Plastics Material and Resin Manufacturing(325211)',
#   'Long term Debt': 3976.98,
#   'Net Sales Revenue Trend (%)': -26.62,
#   'Number of Employees': '190 (2024)',
#   'Operating Profit Trend (%)': -84.14,
#   'Property, plant and equipment': 42645.37,
#   'Return on Assets (ROA) (%)': -1.34,
#   'Return on Equity (ROE) (%)': -2.24,
#   'Quick Ratio (x)': 1.46,
#   'Short Term Debt': 27743.94,
#   'Total operating revenue': 103119.03},
#  {'Company': 'Plasticos Tecnicos S.A.S.',
#   'Cash and Cash Equivalents': 10810.3,
#   'Export': 'SV (3.75%), EC (14.34%), MY (0.5%), CR (1.98%), MX (6.47%), HN (3.26%), BR (16.91%), US (37.2%), PE (0.24%), CL (0.55%), CU (7.35%), DO (0.37%), FR (2.86%), AM (4.22%)',
#   'Import': 'UK (0.47%), AU (0.01%), IE (2.96%), NL (0.7%), BE (6.92%), AT (0.3%), Taiwan, China, KR (7.56%), Denmark, JP (0.06%), CN (15.91%), DE (31.87%), CO (5.13%), RO (0.14%), PL (0.03%), AR (5.51%), IN (0.02%), IT (6.91%), VN (0.01%), BR (2.1%), US (12.73%), FR (0.66%)',
#   'Industry (NAICS)': 'All Other Plastics Product Manufacturing(326199)',
#   'Long term Debt': 8590.09,
#   'Net Sales Revenue Trend (%)': 5.51,
#   'Number of Employees': '584 (2024)',
#   'Operating Profit Trend (%)': 11.22,
#   'Property, plant and equipment': 28506.78,
#   'Return on Assets (ROA) (%)': 8.49,
#   'Return on Equity (ROE) (%)': 20.01,
#   'Quick Ratio (x)': 0.84,
#   'Short Term Debt': 22744.4,
#   'Total operating revenue': 102592.5},
#  {'Company': 'Dispetrocom S.A.S',
#   'Cash and Cash Equivalents': 3895.06,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Petroleum and Petroleum Products Merchant Wholesalers (except Bulk Stations and Terminals)(42472)',
#   'Long term Debt': 2225.21,
#   'Net Sales Revenue Trend (%)': 29.37,
#   'Number of Employees': '65 (2024)',
#   'Operating Profit Trend (%)': 27.7,
#   'Property, plant and equipment': 7445.69,
#   'Return on Assets (ROA) (%)': 2.41,
#   'Return on Equity (ROE) (%)': 18.46,
#   'Quick Ratio (x)': 0.87,
#   'Short Term Debt': 411.37,
#   'Total operating revenue': 102282.01},
#  {'Company': 'Acqua Marketing Colombia S.A.S',
#   'Cash and Cash Equivalents': 4818.69,
#   'Export': 'PA (100%)',
#   'Import': 'ID (7.44%), CN (50.02%), PH (0.28%), KH (8.24%), PK (0.66%), TW (0.01%), VN (25.05%), BA (0.03%), TH (0.42%), TR (0.12%), BD (7.73%)',
#   'Industry (NAICS)': 'Shoe Stores(4482)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -1.31,
#   'Number of Employees': '233 (2023)',
#   'Operating Profit Trend (%)': -41.1,
#   'Property, plant and equipment': 3056.94,
#   'Return on Assets (ROA) (%)': 14.08,
#   'Return on Equity (ROE) (%)': 27.39,
#   'Quick Ratio (x)': 0.44,
#   'Short Term Debt': 17.6,
#   'Total operating revenue': 102132.75},
#  {'Company': 'Tivit Colombia Tercerizacion de Procesos Servicios y Tecnologia Sas',
#   'Cash and Cash Equivalents': 3137.83,
#   'Export': ' ',
#   'Import': 'CN (100%)',
#   'Industry (NAICS)': 'Other Computer Related Services(541519)',
#   'Long term Debt': 6075.99,
#   'Net Sales Revenue Trend (%)': 15.23,
#   'Number of Employees': '652 (2024)',
#   'Operating Profit Trend (%)': -14.55,
#   'Property, plant and equipment': 10742.18,
#   'Return on Assets (ROA) (%)': 5.02,
#   'Return on Equity (ROE) (%)': 9.09,
#   'Quick Ratio (x)': 1.28,
#   'Short Term Debt': 25626.09,
#   'Total operating revenue': 102000.63},
#  {'Company': 'Sony Music Entertainment Colombia S.A.',
#   'Cash and Cash Equivalents': 6675.85,
#   'Export': 'VE (38.63%), EC (45.99%), PE (15.38%)',
#   'Import': 'CZ (34.88%), US (65.12%)',
#   'Industry (NAICS)': 'Sound Recording Industries(5122)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 5.5,
#   'Number of Employees': '59 (2024)',
#   'Operating Profit Trend (%)': -2.14,
#   'Property, plant and equipment': 11121.87,
#   'Return on Assets (ROA) (%)': 8.08,
#   'Return on Equity (ROE) (%)': 30.52,
#   'Quick Ratio (x)': 0.49,
#   'Short Term Debt': 6415.01,
#   'Total operating revenue': 101729.63},
#  {'Company': 'Maple Respiratory I.P.S. S.A.S.',
#   'Cash and Cash Equivalents': 1979.87,
#   'Export': 'US (100%)',
#   'Import': 'DE (0.27%), CN (12.67%), AU (4.08%), SG (41.03%), MX (36%), US (3.74%), NZ (2.21%)',
#   'Industry (NAICS)': 'Nursing Care Facilities (Skilled Nursing Facilities)(6231)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 31.35,
#   'Number of Employees': '274 (2024)',
#   'Operating Profit Trend (%)': 46.46,
#   'Property, plant and equipment': 63034.67,
#   'Return on Assets (ROA) (%)': 14.08,
#   'Return on Equity (ROE) (%)': 23.37,
#   'Quick Ratio (x)': 0.97,
#   'Short Term Debt': 24153.95,
#   'Total operating revenue': 101519.0},
#  {'Company': 'Servicios Geologicos Integrados Sas. S. G. I. Sas',
#   'Cash and Cash Equivalents': 11337.6,
#   'Export': ' ',
#   'Import': 'CN (17.27%), JP (82.73%)',
#   'Industry (NAICS)': 'Engineering Services(54133)',
#   'Long term Debt': 1592.15,
#   'Net Sales Revenue Trend (%)': 2.3,
#   'Number of Employees': '755 (2024)',
#   'Operating Profit Trend (%)': 8.15,
#   'Property, plant and equipment': 9855.22,
#   'Return on Assets (ROA) (%)': 12.16,
#   'Return on Equity (ROE) (%)': 16.99,
#   'Quick Ratio (x)': 2.54,
#   'Short Term Debt': 69.73,
#   'Total operating revenue': 101435.96},
#  {'Company': 'Edgewell Personal Care Colombia S A S',
#   'Cash and Cash Equivalents': 21406.54,
#   'Export': 'EC (17.42%), CL (82.58%)',
#   'Import': 'CN (0.1%), MX (96.82%), UK (0.09%), US (2.99%)',
#   'Industry (NAICS)': "Drugs and Druggists' Sundries Merchant Wholesalers(4242)",
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 7.2,
#   'Number of Employees': '78 (2024)',
#   'Operating Profit Trend (%)': 173.91,
#   'Property, plant and equipment': 258.43,
#   'Return on Assets (ROA) (%)': 7.84,
#   'Return on Equity (ROE) (%)': 16.16,
#   'Quick Ratio (x)': 1.19,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 101393.27},
#  {'Company': 'Danisco Colombia Ltda',
#   'Cash and Cash Equivalents': 8103.38,
#   'Export': 'AU (0.02%), NI (13.89%), NL (7.17%), EC (11.14%), CR (1.33%), GT (8.58%), VE (1.32%), SV (14.19%), AR (0.04%), BR (1.98%), HN (16.32%), PE (11.84%), US (3.42%), FR (1.09%), CL (0.15%), BO (7.52%)',
#   'Import': 'NL (1.24%), BE (0.32%), MY (1.76%), DK (38.7%), JP (2.97%), CN (7.72%), DE (0.04%), FI (0.45%), AR (1.98%), CH (0.17%), IN (0.01%), MX (3.41%), BR (19.49%), US (20.1%), TH (0.22%), ES (0.12%), CL (0.69%), FR (0.61%)',
#   'Industry (NAICS)': 'Farm Product Raw Material Merchant Wholesalers(4245)',
#   'Long term Debt': 3048.45,
#   'Net Sales Revenue Trend (%)': -11.72,
#   'Number of Employees': '58 (2024)',
#   'Operating Profit Trend (%)': -110.96,
#   'Property, plant and equipment': 2841.41,
#   'Return on Assets (ROA) (%)': -2.41,
#   'Return on Equity (ROE) (%)': -3.96,
#   'Quick Ratio (x)': 1.68,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 100856.63},
#  {'Company': 'Creative Colors S A',
#   'Cash and Cash Equivalents': 19395.52,
#   'Export': ' ',
#   'Import': 'DE (4.64%), CN (35.03%), IE (0.69%), BE (0.03%), TW (1.95%), BR (38.04%), CZ (16.94%), US (1.5%), SK (0.61%), JP (0.5%), FR (0.07%)',
#   'Industry (NAICS)': 'Soap, Cleaning Compound, and Toilet Preparation Manufacturing(3256)',
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -5.93,
#   'Number of Employees': '176 (2024)',
#   'Operating Profit Trend (%)': -22.82,
#   'Property, plant and equipment': 16044.31,
#   'Return on Assets (ROA) (%)': 35.83,
#   'Return on Equity (ROE) (%)': 46.88,
#   'Quick Ratio (x)': 2.2,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 100841.57},
#  {'Company': 'Inversiones y Asesorias de Transportes Andino S A',
#   'Cash and Cash Equivalents': 340.78,
#   'Export': ' ',
#   'Import': ' ',
#   'Industry (NAICS)': 'Gasoline Stations(4471)',
#   'Long term Debt': 13458.77,
#   'Net Sales Revenue Trend (%)': 45.34,
#   'Number of Employees': '98 (2024)',
#   'Operating Profit Trend (%)': 66.18,
#   'Property, plant and equipment': 20933.61,
#   'Return on Assets (ROA) (%)': 0.66,
#   'Return on Equity (ROE) (%)': 3.2,
#   'Quick Ratio (x)': 1.59,
#   'Short Term Debt': 1178.86,
#   'Total operating revenue': 100711.91},
#  ...]

# %%
URL = "http://0.0.0.0:8000/"
result_total = consume_classifier_api(URL, payload2)
result_total
# Out:
# [{'Company': 'Ecopetrol S.A.',
#   'Cash and Cash Equivalents': 12336115.05,
#   'Long term Debt': 90265519.23,
#   'Net Sales Revenue Trend (%)': -10.28,
#   'Operating Profit Trend (%)': -30.69,
#   'Property, plant and equipment': 95171301.6,
#   'Return on Assets (ROA) (%)': 8.26,
#   'Return on Equity (ROE) (%)': 22.6,
#   'Quick Ratio (x)': 1.34,
#   'Short Term Debt': 15550007.72,
#   'Total operating revenue': 142748516.61,
#   'Employees': 19601.0,
#   'Export_CN': 10.36,
#   'Import_CN': 0.13,
#   'Export_US': 32.37,
#   'Import_US': 71.54,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.08,
#   'Import_MX': 0.05,
#   'Export_ES': 3.39,
#   'Import_ES': 2.82,
#   'Export_DE': 0.0,
#   'Import_DE': 0.15,
#   'Export_BR': 0.0,
#   'Import_BR': 2.56,
#   'Export_PE': 0.39,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.23,
#   'Export_PA': 28.55,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 1.1118428052,
#   'Relative_Growth': 20.41,
#   'cluster': 4},
#  {'Company': 'Organizacion Terpel S.A.',
#   'Cash and Cash Equivalents': 916490.75,
#   'Long term Debt': 3171446.29,
#   'Net Sales Revenue Trend (%)': 2.17,
#   'Operating Profit Trend (%)': 10.06,
#   'Property, plant and equipment': 3939357.24,
#   'Return on Assets (ROA) (%)': 3.06,
#   'Return on Equity (ROE) (%)': 10.37,
#   'Quick Ratio (x)': 0.89,
#   'Short Term Debt': 1088524.14,
#   'Total operating revenue': 36252719.63,
#   'Employees': 1582.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.38,
#   'Export_US': 21.37,
#   'Import_US': 96.06,
#   'Export_EC': 3.59,
#   'Import_EC': 0.0,
#   'Export_MX': 0.42,
#   'Import_MX': 0.0,
#   'Export_ES': 0.07,
#   'Import_ES': 0.06,
#   'Export_DE': 0.0,
#   'Import_DE': 0.45,
#   'Export_BR': 0.1,
#   'Import_BR': 0.0,
#   'Export_PE': 0.58,
#   'Import_PE': 0.45,
#   'Export_IT': 0.0,
#   'Import_IT': 0.08,
#   'Export_PA': 4.19,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 1.0813871834,
#   'Relative_Growth': -7.89,
#   'cluster': 10},
#  {'Company': 'D1 S A S',
#   'Cash and Cash Equivalents': 718512.83,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 24.88,
#   'Operating Profit Trend (%)': 1.75,
#   'Property, plant and equipment': 3379990.01,
#   'Return on Assets (ROA) (%)': 5.19,
#   'Return on Equity (ROE) (%)': 167.99,
#   'Quick Ratio (x)': 0.33,
#   'Short Term Debt': 9555.73,
#   'Total operating revenue': 17424130.56,
#   'Employees': 19780.0,
#   'Export_CN': 0.0,
#   'Import_CN': 8.14,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 100.0,
#   'Import_EC': 22.67,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 20.69,
#   'Export_DE': 0.0,
#   'Import_DE': 3.29,
#   'Export_BR': 0.0,
#   'Import_BR': 0.12,
#   'Export_PE': 0.0,
#   'Import_PE': 2.55,
#   'Export_IT': 0.0,
#   'Import_IT': 11.84,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.0028271474,
#   'Relative_Growth': 23.13,
#   'cluster': 23},
#  {'Company': 'Enel Colombia S.A. E.S.P.',
#   'Cash and Cash Equivalents': 1629477.08,
#   'Long term Debt': 7253638.57,
#   'Net Sales Revenue Trend (%)': 37.18,
#   'Operating Profit Trend (%)': -3.57,
#   'Property, plant and equipment': 21758779.81,
#   'Return on Assets (ROA) (%)': 6.6,
#   'Return on Equity (ROE) (%)': 13.98,
#   'Quick Ratio (x)': 0.74,
#   'Short Term Debt': 2180692.21,
#   'Total operating revenue': 16724866.7,
#   'Employees': 2601.0,
#   'Export_CN': 0.0,
#   'Import_CN': 80.97,
#   'Export_US': 0.08,
#   'Import_US': 0.43,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.14,
#   'Export_ES': 0.0,
#   'Import_ES': 5.55,
#   'Export_DE': 0.0,
#   'Import_DE': 0.07,
#   'Export_BR': 0.0,
#   'Import_BR': 1.25,
#   'Export_PE': 0.0,
#   'Import_PE': 1.02,
#   'Export_IT': 0.0,
#   'Import_IT': 4.27,
#   'Export_PA': 99.92,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Públicos',
#   'Debt_to_Assets': 0.4335873088,
#   'Relative_Growth': 40.75,
#   'cluster': 7},
#  {'Company': 'Drummond Ltd',
#   'Cash and Cash Equivalents': 169861.35,
#   'Long term Debt': 150353.59,
#   'Net Sales Revenue Trend (%)': 1.55,
#   'Operating Profit Trend (%)': 6.54,
#   'Property, plant and equipment': 5480302.25,
#   'Return on Assets (ROA) (%)': 27.61,
#   'Return on Equity (ROE) (%)': 40.46,
#   'Quick Ratio (x)': 1.8,
#   'Short Term Debt': 106914.23,
#   'Total operating revenue': 15424348.8,
#   'Employees': 5340.0,
#   'Export_CN': 3.08,
#   'Import_CN': 3.14,
#   'Export_US': 3.74,
#   'Import_US': 66.98,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 15.17,
#   'Import_MX': 3.85,
#   'Export_ES': 2.43,
#   'Import_ES': 0.57,
#   'Export_DE': 0.87,
#   'Import_DE': 13.18,
#   'Export_BR': 2.8,
#   'Import_BR': 0.56,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 1.6,
#   'Export_PA': 1.66,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0469440933,
#   'Relative_Growth': -4.99,
#   'cluster': 10},
#  {'Company': 'Comunicacion Celular S A Comcel S A',
#   'Cash and Cash Equivalents': 354995.14,
#   'Long term Debt': 1745160.97,
#   'Net Sales Revenue Trend (%)': 1.64,
#   'Operating Profit Trend (%)': -22.92,
#   'Property, plant and equipment': 11498788.34,
#   'Return on Assets (ROA) (%)': 5.86,
#   'Return on Equity (ROE) (%)': 13.85,
#   'Quick Ratio (x)': 1.17,
#   'Short Term Debt': 520160.92,
#   'Total operating revenue': 14853248.62,
#   'Employees': 9492.0,
#   'Export_CN': 0.0,
#   'Import_CN': 62.77,
#   'Export_US': 4.02,
#   'Import_US': 2.52,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 71.23,
#   'Import_MX': 6.26,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Información y Tecnología',
#   'Debt_to_Assets': 0.197005269,
#   'Relative_Growth': 24.56,
#   'cluster': 13},
#  {'Company': 'Jeronimo Martins Colombia Sas',
#   'Cash and Cash Equivalents': 445768.23,
#   'Long term Debt': 699134.53,
#   'Net Sales Revenue Trend (%)': 43.27,
#   'Operating Profit Trend (%)': 1549.59,
#   'Property, plant and equipment': 3296243.22,
#   'Return on Assets (ROA) (%)': -9.21,
#   'Return on Equity (ROE) (%)': -522.59,
#   'Quick Ratio (x)': 0.14,
#   'Short Term Debt': 1950722.58,
#   'Total operating revenue': 12352070.91,
#   'Employees': 12482.0,
#   'Export_CN': 0.0,
#   'Import_CN': 28.91,
#   'Export_US': 0.0,
#   'Import_US': 0.76,
#   'Export_EC': 46.13,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 13.43,
#   'Export_DE': 0.0,
#   'Import_DE': 5.66,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 53.87,
#   'Import_IT': 11.19,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.8039021799,
#   'Relative_Growth': -1506.32,
#   'cluster': 11},
#  {'Company': 'Colombiana de Comercio S.A.',
#   'Cash and Cash Equivalents': 467037.66,
#   'Long term Debt': 196537.93,
#   'Net Sales Revenue Trend (%)': -0.08,
#   'Operating Profit Trend (%)': -9.82,
#   'Property, plant and equipment': 1341359.38,
#   'Return on Assets (ROA) (%)': 5.35,
#   'Return on Equity (ROE) (%)': 11.87,
#   'Quick Ratio (x)': 0.62,
#   'Short Term Debt': 369297.09,
#   'Total operating revenue': 11148835.22,
#   'Employees': 12772.0,
#   'Export_CN': 0.0,
#   'Import_CN': 80.87,
#   'Export_US': 0.0,
#   'Import_US': 2.62,
#   'Export_EC': 0.0,
#   'Import_EC': 0.52,
#   'Export_MX': 4.45,
#   'Import_MX': 6.43,
#   'Export_ES': 0.0,
#   'Import_ES': 0.2,
#   'Export_DE': 0.0,
#   'Import_DE': 1.25,
#   'Export_BR': 0.0,
#   'Import_BR': 0.39,
#   'Export_PE': 0.0,
#   'Import_PE': 0.08,
#   'Export_IT': 0.0,
#   'Import_IT': 0.06,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.4218370024,
#   'Relative_Growth': 9.74,
#   'cluster': 7},
#  {'Company': 'Kopps Commercial S.A.S',
#   'Cash and Cash Equivalents': 3953511.43,
#   'Long term Debt': 463100.06,
#   'Net Sales Revenue Trend (%)': 11.77,
#   'Operating Profit Trend (%)': 12.06,
#   'Property, plant and equipment': 752873.87,
#   'Return on Assets (ROA) (%)': 16.39,
#   'Return on Equity (ROE) (%)': 83.06,
#   'Quick Ratio (x)': 1.17,
#   'Short Term Debt': 52318.82,
#   'Total operating revenue': 10635671.37,
#   'Employees': 654.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 84.41,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 15.59,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.6846018975,
#   'Relative_Growth': -0.29,
#   'cluster': 10},
#  {'Company': 'Primax Colombia S.A.',
#   'Cash and Cash Equivalents': 94148.67,
#   'Long term Debt': 434602.55,
#   'Net Sales Revenue Trend (%)': 16.43,
#   'Operating Profit Trend (%)': 36.87,
#   'Property, plant and equipment': 785141.85,
#   'Return on Assets (ROA) (%)': 4.32,
#   'Return on Equity (ROE) (%)': 16.17,
#   'Quick Ratio (x)': 0.48,
#   'Short Term Debt': 174446.95,
#   'Total operating revenue': 9045379.71,
#   'Employees': 148.0,
#   'Export_CN': 0.0,
#   'Import_CN': 8.56,
#   'Export_US': 0.0,
#   'Import_US': 89.56,
#   'Export_EC': 34.4,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 30.86,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 7.83,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.7757190627,
#   'Relative_Growth': -20.44,
#   'cluster': 10},
#  {'Company': 'Grupo Energia Bogota S.A.E.S.P.',
#   'Cash and Cash Equivalents': 2289704.0,
#   'Long term Debt': 16538242.0,
#   'Net Sales Revenue Trend (%)': 16.06,
#   'Operating Profit Trend (%)': -70.27,
#   'Property, plant and equipment': 15922277.0,
#   'Return on Assets (ROA) (%)': 0.77,
#   'Return on Equity (ROE) (%)': 1.71,
#   'Quick Ratio (x)': 1.25,
#   'Short Term Debt': 2429575.0,
#   'Total operating revenue': 7988164.0,
#   'Employees': 401.0,
#   'Export_CN': 0.0,
#   'Import_CN': 7.29,
#   'Export_US': 0.0,
#   'Import_US': 0.02,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 1.73,
#   'Export_DE': 0.0,
#   'Import_DE': 7.01,
#   'Export_BR': 0.0,
#   'Import_BR': 23.89,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 2.02,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Públicos',
#   'Debt_to_Assets': 1.1912754061,
#   'Relative_Growth': 86.33,
#   'cluster': 0},
#  {'Company': 'Caja de Compensacion Familiar COMPENSAR',
#   'Cash and Cash Equivalents': 457096.09,
#   'Long term Debt': 164346.19,
#   'Net Sales Revenue Trend (%)': 18.13,
#   'Operating Profit Trend (%)': -177.84,
#   'Property, plant and equipment': 1793318.66,
#   'Return on Assets (ROA) (%)': 2.54,
#   'Return on Equity (ROE) (%)': 6.72,
#   'Quick Ratio (x)': 1.32,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 7557677.15,
#   'Employees': 9172.0,
#   'Export_CN': 0.0,
#   'Import_CN': 2.92,
#   'Export_US': 0.0,
#   'Import_US': 88.1,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 2.14,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 0.0916436067,
#   'Relative_Growth': 195.97,
#   'cluster': 10},
#  {'Company': 'Colombia Telecommunications S.A. E.S.P. (Movistar Colombia)',
#   'Cash and Cash Equivalents': 362205.67,
#   'Long term Debt': 4957301.57,
#   'Net Sales Revenue Trend (%)': -0.98,
#   'Operating Profit Trend (%)': -84.39,
#   'Property, plant and equipment': 3956375.04,
#   'Return on Assets (ROA) (%)': -5.14,
#   'Return on Equity (ROE) (%)': -17.45,
#   'Quick Ratio (x)': 0.59,
#   'Short Term Debt': 1385317.75,
#   'Total operating revenue': 7122914.83,
#   'Employees': 5623.0,
#   'Export_CN': 0.0,
#   'Import_CN': 79.19,
#   'Export_US': 0.0,
#   'Import_US': 0.47,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 1.4,
#   'Export_ES': 0.0,
#   'Import_ES': 0.37,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 4.63,
#   'Export_PE': 7.38,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Información y Tecnología',
#   'Debt_to_Assets': 1.6031390492,
#   'Relative_Growth': 83.41,
#   'cluster': 7},
#  {'Company': 'Cenit Transporte y Logistica de Hidrocarburos S A S',
#   'Cash and Cash Equivalents': 1147503.24,
#   'Long term Debt': 68050.6,
#   'Net Sales Revenue Trend (%)': 24.09,
#   'Operating Profit Trend (%)': 11.26,
#   'Property, plant and equipment': 11605880.87,
#   'Return on Assets (ROA) (%)': 24.02,
#   'Return on Equity (ROE) (%)': 28.34,
#   'Quick Ratio (x)': 1.78,
#   'Short Term Debt': 246770.89,
#   'Total operating revenue': 7113995.49,
#   'Employees': 1140.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 31.2,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 100.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Transporte y Almacenamiento',
#   'Debt_to_Assets': 0.0271260315,
#   'Relative_Growth': 12.83,
#   'cluster': 15},
#  {'Company': 'Carbones del Cerrejon Limited',
#   'Cash and Cash Equivalents': 2268.49,
#   'Long term Debt': 553941.86,
#   'Net Sales Revenue Trend (%)': -54.42,
#   'Operating Profit Trend (%)': -95.04,
#   'Property, plant and equipment': 4392545.89,
#   'Return on Assets (ROA) (%)': 2.79,
#   'Return on Equity (ROE) (%)': 5.2,
#   'Quick Ratio (x)': 1.91,
#   'Short Term Debt': 12910.98,
#   'Total operating revenue': 6976125.26,
#   'Employees': 5501.0,
#   'Export_CN': 9.83,
#   'Import_CN': 1.78,
#   'Export_US': 0.37,
#   'Import_US': 67.53,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 3.14,
#   'Export_ES': 2.42,
#   'Import_ES': 0.23,
#   'Export_DE': 3.19,
#   'Import_DE': 1.84,
#   'Export_BR': 2.07,
#   'Import_BR': 0.09,
#   'Export_PE': 0.0,
#   'Import_PE': 0.1,
#   'Export_IT': 2.86,
#   'Import_IT': 0.72,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.1290488146,
#   'Relative_Growth': 40.62,
#   'cluster': 10},
#  {'Company': 'Salud Total Entidad Promotora de Salud del Regimen Contributivo y del Regimen Subsidiado S.A.',
#   'Cash and Cash Equivalents': 68744.72,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.1,
#   'Operating Profit Trend (%)': -400.51,
#   'Property, plant and equipment': 69972.99,
#   'Return on Assets (ROA) (%)': 3.17,
#   'Return on Equity (ROE) (%)': 28.65,
#   'Quick Ratio (x)': 2.37,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6910340.0,
#   'Employees': 2000.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Administración Pública',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 415.61,
#   'cluster': 0},
#  {'Company': 'Caja Colombiana de Subsidio Familiar COLSUBSIDIO',
#   'Cash and Cash Equivalents': 112663.16,
#   'Long term Debt': 561067.61,
#   'Net Sales Revenue Trend (%)': 16.88,
#   'Operating Profit Trend (%)': 1.72,
#   'Property, plant and equipment': 1726188.21,
#   'Return on Assets (ROA) (%)': 2.1,
#   'Return on Equity (ROE) (%)': 5.38,
#   'Quick Ratio (x)': 1.04,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6783544.32,
#   'Employees': 10000.0,
#   'Export_CN': 0.0,
#   'Import_CN': 13.06,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 12.37,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 14.7,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 0.3250326973,
#   'Relative_Growth': 15.16,
#   'cluster': 0},
#  {'Company': 'Positiva Compania de Seguros Sa',
#   'Cash and Cash Equivalents': 280306.77,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.9,
#   'Operating Profit Trend (%)': 43.94,
#   'Property, plant and equipment': 99737.21,
#   'Return on Assets (ROA) (%)': 3.16,
#   'Return on Equity (ROE) (%)': 20.32,
#   'Quick Ratio (x)': 1.07,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 6656322.48,
#   'Employees': 766.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': -28.04,
#   'cluster': 0},
#  {'Company': 'C.I. Trafigura Petroleum Colombia S.A.S.',
#   'Cash and Cash Equivalents': 7878.35,
#   'Long term Debt': 3376.08,
#   'Net Sales Revenue Trend (%)': -3.64,
#   'Operating Profit Trend (%)': -114.09,
#   'Property, plant and equipment': 0.0,
#   'Return on Assets (ROA) (%)': 0.37,
#   'Return on Equity (ROE) (%)': 8.57,
#   'Quick Ratio (x)': 0.76,
#   'Short Term Debt': 537.13,
#   'Total operating revenue': 6334602.41,
#   'Employees': 4.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 38.7,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 7.83,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 6.89,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 27.54,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 110.45,
#   'cluster': 0},
#  {'Company': 'Bavaria & Cia S.C.A',
#   'Cash and Cash Equivalents': 608964.04,
#   'Long term Debt': 75601.53,
#   'Net Sales Revenue Trend (%)': 9.38,
#   'Operating Profit Trend (%)': -9.48,
#   'Property, plant and equipment': 3707545.0,
#   'Return on Assets (ROA) (%)': 17.37,
#   'Return on Equity (ROE) (%)': 76.81,
#   'Quick Ratio (x)': 0.88,
#   'Short Term Debt': 489123.57,
#   'Total operating revenue': 6235011.18,
#   'Employees': 2749.0,
#   'Export_CN': 0.0,
#   'Import_CN': 6.46,
#   'Export_US': 9.21,
#   'Import_US': 6.58,
#   'Export_EC': 20.16,
#   'Import_EC': 1.3,
#   'Export_MX': 0.02,
#   'Import_MX': 18.53,
#   'Export_ES': 1.94,
#   'Import_ES': 0.15,
#   'Export_DE': 0.0,
#   'Import_DE': 3.6,
#   'Export_BR': 4.69,
#   'Import_BR': 7.7,
#   'Export_PE': 25.6,
#   'Import_PE': 2.62,
#   'Export_IT': 0.0,
#   'Import_IT': 1.24,
#   'Export_PA': 6.17,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.1523178006,
#   'Relative_Growth': 18.86,
#   'cluster': 0},
#  {'Company': 'Oleoducto Central S.A.',
#   'Cash and Cash Equivalents': 1095721.97,
#   'Long term Debt': 1548301.08,
#   'Net Sales Revenue Trend (%)': 11.36,
#   'Operating Profit Trend (%)': 11.86,
#   'Property, plant and equipment': 4811039.19,
#   'Return on Assets (ROA) (%)': 42.31,
#   'Return on Equity (ROE) (%)': 75.57,
#   'Quick Ratio (x)': 1.82,
#   'Short Term Debt': 104578.68,
#   'Total operating revenue': 6143100.32,
#   'Employees': 275.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.56,
#   'Export_US': 0.0,
#   'Import_US': 31.08,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 7.95,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 26.02,
#   'Export_BR': 0.0,
#   'Import_BR': 0.05,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.6,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Transporte y Almacenamiento',
#   'Debt_to_Assets': 0.3435598204,
#   'Relative_Growth': -0.5,
#   'cluster': 0},
#  {'Company': 'Sodimac Colombia S.A.',
#   'Cash and Cash Equivalents': 346045.27,
#   'Long term Debt': 1501006.75,
#   'Net Sales Revenue Trend (%)': -4.06,
#   'Operating Profit Trend (%)': -1.3,
#   'Property, plant and equipment': 2326729.42,
#   'Return on Assets (ROA) (%)': 7.62,
#   'Return on Equity (ROE) (%)': 18.45,
#   'Quick Ratio (x)': 0.79,
#   'Short Term Debt': 64432.56,
#   'Total operating revenue': 5761589.34,
#   'Employees': 9181.0,
#   'Export_CN': 88.68,
#   'Import_CN': 76.25,
#   'Export_US': 0.0,
#   'Import_US': 0.72,
#   'Export_EC': 11.32,
#   'Import_EC': 0.19,
#   'Export_MX': 0.0,
#   'Import_MX': 0.86,
#   'Export_ES': 0.0,
#   'Import_ES': 3.0,
#   'Export_DE': 0.0,
#   'Import_DE': 1.54,
#   'Export_BR': 0.0,
#   'Import_BR': 3.49,
#   'Export_PE': 0.0,
#   'Import_PE': 0.94,
#   'Export_IT': 0.0,
#   'Import_IT': 0.08,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.6728067718,
#   'Relative_Growth': -2.76,
#   'cluster': 3},
#  {'Company': 'Chevron Petroleum Company',
#   'Cash and Cash Equivalents': 82276.0,
#   'Long term Debt': 3165.0,
#   'Net Sales Revenue Trend (%)': 25.66,
#   'Operating Profit Trend (%)': -320.9,
#   'Property, plant and equipment': 646002.0,
#   'Return on Assets (ROA) (%)': 0.84,
#   'Return on Equity (ROE) (%)': 15.61,
#   'Quick Ratio (x)': 0.78,
#   'Short Term Debt': 52288.0,
#   'Total operating revenue': 5720906.0,
#   'Employees': 189.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 6.58,
#   'Import_US': 93.57,
#   'Export_EC': 20.76,
#   'Import_EC': 0.0,
#   'Export_MX': 1.41,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.07,
#   'Export_BR': 0.0,
#   'Import_BR': 2.15,
#   'Export_PE': 41.25,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.34,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.0858402915,
#   'Relative_Growth': 346.56,
#   'cluster': 10},
#  {'Company': 'Verano Energy (Switzerland) Ag Sucursal',
#   'Cash and Cash Equivalents': 128849.35,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 18.94,
#   'Operating Profit Trend (%)': -128.66,
#   'Property, plant and equipment': 5145558.99,
#   'Return on Assets (ROA) (%)': 4.19,
#   'Return on Equity (ROE) (%)': 11.86,
#   'Quick Ratio (x)': 3.18,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 5407766.82,
#   'Employees': 49.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 147.6,
#   'cluster': 0},
#  {'Company': 'Droguerias y Farmacias Cruz Verde S.A.S',
#   'Cash and Cash Equivalents': 19121.87,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 20.63,
#   'Operating Profit Trend (%)': -100.45,
#   'Property, plant and equipment': 173459.55,
#   'Return on Assets (ROA) (%)': -1.54,
#   'Return on Equity (ROE) (%)': -8.25,
#   'Quick Ratio (x)': 0.7,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 5127429.73,
#   'Employees': 7743.0,
#   'Export_CN': 0.0,
#   'Import_CN': 4.03,
#   'Export_US': 0.0,
#   'Import_US': 13.46,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 8.82,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.18,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 121.08,
#   'cluster': 0},
#  {'Company': 'Industria Nacional de Gaseosas S.A.',
#   'Cash and Cash Equivalents': 132836.18,
#   'Long term Debt': 230000.0,
#   'Net Sales Revenue Trend (%)': 21.55,
#   'Operating Profit Trend (%)': 38.49,
#   'Property, plant and equipment': 1645822.41,
#   'Return on Assets (ROA) (%)': -1.56,
#   'Return on Equity (ROE) (%)': -5.66,
#   'Quick Ratio (x)': 0.4,
#   'Short Term Debt': 32486.44,
#   'Total operating revenue': 4878634.49,
#   'Employees': 1741.0,
#   'Export_CN': 0.0,
#   'Import_CN': 1.32,
#   'Export_US': 0.0,
#   'Import_US': 2.32,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 8.56,
#   'Export_ES': 0.0,
#   'Import_ES': 0.3,
#   'Export_DE': 25.19,
#   'Import_DE': 16.75,
#   'Export_BR': 0.0,
#   'Import_BR': 54.62,
#   'Export_PE': 0.07,
#   'Import_PE': 3.69,
#   'Export_IT': 5.51,
#   'Import_IT': 1.64,
#   'Export_PA': 15.5,
#   'Import_PA': 0.01,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.1594864904,
#   'Relative_Growth': -16.94,
#   'cluster': 19},
#  {'Company': 'Frontera Energy Colombia Corp., Sucursal Colombia',
#   'Cash and Cash Equivalents': 101252.47,
#   'Long term Debt': 48007.08,
#   'Net Sales Revenue Trend (%)': -10.56,
#   'Operating Profit Trend (%)': -50.78,
#   'Property, plant and equipment': 5811742.02,
#   'Return on Assets (ROA) (%)': 7.9,
#   'Return on Equity (ROE) (%)': 10.77,
#   'Quick Ratio (x)': 0.71,
#   'Short Term Debt': 93436.66,
#   'Total operating revenue': 4741579.92,
#   'Employees': 795.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.34,
#   'Export_US': 24.2,
#   'Import_US': 99.33,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.18,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 64.44,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0243375806,
#   'Relative_Growth': 40.22,
#   'cluster': 10},
#  {'Company': 'Grupo Bolivar S.A.',
#   'Cash and Cash Equivalents': 15470750.82,
#   'Long term Debt': 63370605.89,
#   'Net Sales Revenue Trend (%)': -89.23,
#   'Operating Profit Trend (%)': -163.13,
#   'Property, plant and equipment': 1946516.52,
#   'Return on Assets (ROA) (%)': 0.1,
#   'Return on Equity (ROE) (%)': 1.04,
#   'Quick Ratio (x)': 1.8,
#   'Short Term Debt': 99837325.25,
#   'Total operating revenue': 4637664.28,
#   'Employees': 10.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 2.09,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 6.36,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 83.8461577197,
#   'Relative_Growth': 73.9,
#   'cluster': 4},
#  {'Company': 'Cencosud Colombia S.A.',
#   'Cash and Cash Equivalents': 103018.06,
#   'Long term Debt': 75810.69,
#   'Net Sales Revenue Trend (%)': -4.56,
#   'Operating Profit Trend (%)': -120.0,
#   'Property, plant and equipment': 2080917.79,
#   'Return on Assets (ROA) (%)': -0.08,
#   'Return on Equity (ROE) (%)': -0.12,
#   'Quick Ratio (x)': 0.43,
#   'Short Term Debt': 22795.37,
#   'Total operating revenue': 4429314.08,
#   'Employees': 10277.0,
#   'Export_CN': 0.0,
#   'Import_CN': 52.7,
#   'Export_US': 0.0,
#   'Import_US': 8.39,
#   'Export_EC': 0.0,
#   'Import_EC': 3.58,
#   'Export_MX': 0.0,
#   'Import_MX': 1.2,
#   'Export_ES': 0.0,
#   'Import_ES': 7.84,
#   'Export_DE': 0.0,
#   'Import_DE': 1.67,
#   'Export_BR': 0.0,
#   'Import_BR': 2.73,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 3.77,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.0473858508,
#   'Relative_Growth': 115.44,
#   'cluster': 7},
#  {'Company': 'Automotores Toyota Colombia S A S',
#   'Cash and Cash Equivalents': 241560.83,
#   'Long term Debt': 135610.23,
#   'Net Sales Revenue Trend (%)': 16.37,
#   'Operating Profit Trend (%)': 42.0,
#   'Property, plant and equipment': 10201.5,
#   'Return on Assets (ROA) (%)': 26.4,
#   'Return on Equity (ROE) (%)': 82.63,
#   'Quick Ratio (x)': 0.7,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 4163114.54,
#   'Employees': 181.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.02,
#   'Export_US': 0.0,
#   'Import_US': 0.12,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 25.99,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 13.2931657109,
#   'Relative_Growth': -25.63,
#   'cluster': 0},
#  {'Company': 'La Previsora S A Compania de Seguros',
#   'Cash and Cash Equivalents': 225547.85,
#   'Long term Debt': 3285.48,
#   'Net Sales Revenue Trend (%)': 35.96,
#   'Operating Profit Trend (%)': -310.05,
#   'Property, plant and equipment': 57073.07,
#   'Return on Assets (ROA) (%)': 4.33,
#   'Return on Equity (ROE) (%)': 27.24,
#   'Quick Ratio (x)': 4.29,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 3781899.45,
#   'Employees': 1532.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 0.0575662042,
#   'Relative_Growth': 346.01,
#   'cluster': 0},
#  {'Company': 'Biomax Biocombustibles S.A.',
#   'Cash and Cash Equivalents': 47398.01,
#   'Long term Debt': 611591.49,
#   'Net Sales Revenue Trend (%)': 22.11,
#   'Operating Profit Trend (%)': 47.48,
#   'Property, plant and equipment': 181881.61,
#   'Return on Assets (ROA) (%)': 4.43,
#   'Return on Equity (ROE) (%)': 12.87,
#   'Quick Ratio (x)': 0.44,
#   'Short Term Debt': 99525.9,
#   'Total operating revenue': 3727003.2,
#   'Employees': 286.0,
#   'Export_CN': 0.0,
#   'Import_CN': 1.85,
#   'Export_US': 0.0,
#   'Import_US': 96.11,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 1.78,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 3.9097816981,
#   'Relative_Growth': -25.37,
#   'cluster': 10},
#  {'Company': 'Italcol S.A.',
#   'Cash and Cash Equivalents': 4751.79,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 6.36,
#   'Operating Profit Trend (%)': 83.88,
#   'Property, plant and equipment': 260619.77,
#   'Return on Assets (ROA) (%)': 12.86,
#   'Return on Equity (ROE) (%)': 26.03,
#   'Quick Ratio (x)': 0.55,
#   'Short Term Debt': 6274.47,
#   'Total operating revenue': 3654627.67,
#   'Employees': 289.0,
#   'Export_CN': 0.0,
#   'Import_CN': 7.66,
#   'Export_US': 0.0,
#   'Import_US': 67.92,
#   'Export_EC': 42.89,
#   'Import_EC': 0.08,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.38,
#   'Export_DE': 0.0,
#   'Import_DE': 0.07,
#   'Export_BR': 0.0,
#   'Import_BR': 13.2,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.23,
#   'Export_PA': 37.37,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.0240751882,
#   'Relative_Growth': -77.52,
#   'cluster': 10},
#  {'Company': 'Cerrejon Zona Norte S.A.',
#   'Cash and Cash Equivalents': 12705.38,
#   'Long term Debt': 63696.13,
#   'Net Sales Revenue Trend (%)': -50.68,
#   'Operating Profit Trend (%)': -83.45,
#   'Property, plant and equipment': 3048048.54,
#   'Return on Assets (ROA) (%)': 13.27,
#   'Return on Equity (ROE) (%)': 16.89,
#   'Quick Ratio (x)': 14.95,
#   'Short Term Debt': 23047.92,
#   'Total operating revenue': 3632510.26,
#   'Employees': 9.0,
#   'Export_CN': 5.23,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 1.37,
#   'Import_ES': 0.0,
#   'Export_DE': 3.03,
#   'Import_DE': 0.0,
#   'Export_BR': 2.15,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 3.23,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0284588808,
#   'Relative_Growth': 32.77,
#   'cluster': 0},
#  {'Company': 'Fondo Nacional del Cafe',
#   'Cash and Cash Equivalents': 310982.88,
#   'Long term Debt': 198746.6,
#   'Net Sales Revenue Trend (%)': -11.14,
#   'Operating Profit Trend (%)': -104.04,
#   'Property, plant and equipment': 893706.89,
#   'Return on Assets (ROA) (%)': -5.17,
#   'Return on Equity (ROE) (%)': -16.89,
#   'Quick Ratio (x)': 0.39,
#   'Short Term Debt': 1563029.03,
#   'Total operating revenue': 3324858.52,
#   'Employees': 3071.0,
#   'Export_CN': 1.37,
#   'Import_CN': 0.09,
#   'Export_US': 26.58,
#   'Import_US': 2.5,
#   'Export_EC': 1.75,
#   'Import_EC': 0.0,
#   'Export_MX': 5.39,
#   'Import_MX': 0.0,
#   'Export_ES': 2.22,
#   'Import_ES': 0.0,
#   'Export_DE': 6.85,
#   'Import_DE': 22.49,
#   'Export_BR': 0.0,
#   'Import_BR': 30.49,
#   'Export_PE': 0.43,
#   'Import_PE': 0.0,
#   'Export_IT': 1.33,
#   'Import_IT': 0.64,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 1.9713125743,
#   'Relative_Growth': 92.9,
#   'cluster': 0},
#  {'Company': 'Caja de Compensacion Familiar CAFAM',
#   'Cash and Cash Equivalents': 99677.32,
#   'Long term Debt': 352170.32,
#   'Net Sales Revenue Trend (%)': 15.18,
#   'Operating Profit Trend (%)': -975.78,
#   'Property, plant and equipment': 2714672.48,
#   'Return on Assets (ROA) (%)': 1.27,
#   'Return on Equity (ROE) (%)': 2.81,
#   'Quick Ratio (x)': 0.74,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 3209832.33,
#   'Employees': 10088.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Finanzas y Seguros',
#   'Debt_to_Assets': 0.1297284746,
#   'Relative_Growth': 990.96,
#   'cluster': 0},
#  {'Company': 'Samsung Electronics Colombia S A',
#   'Cash and Cash Equivalents': 65559.25,
#   'Long term Debt': 3572.76,
#   'Net Sales Revenue Trend (%)': -28.02,
#   'Operating Profit Trend (%)': -34.89,
#   'Property, plant and equipment': 3923.05,
#   'Return on Assets (ROA) (%)': 2.44,
#   'Return on Equity (ROE) (%)': 11.94,
#   'Quick Ratio (x)': 1.06,
#   'Short Term Debt': 2785.5,
#   'Total operating revenue': 3126845.17,
#   'Employees': 181.0,
#   'Export_CN': 0.0,
#   'Import_CN': 11.08,
#   'Export_US': 46.49,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 2.11,
#   'Import_MX': 33.28,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 1.93,
#   'Import_DE': 0.0,
#   'Export_BR': 1.45,
#   'Import_BR': 0.0,
#   'Export_PE': 37.19,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.14,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 1.6207440639,
#   'Relative_Growth': 6.87,
#   'cluster': 1},
#  {'Company': 'Geopark Colombia Sas',
#   'Cash and Cash Equivalents': 414209.01,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -27.67,
#   'Operating Profit Trend (%)': -35.62,
#   'Property, plant and equipment': 2359569.61,
#   'Return on Assets (ROA) (%)': 20.74,
#   'Return on Equity (ROE) (%)': 35.42,
#   'Quick Ratio (x)': 1.07,
#   'Short Term Debt': 268.86,
#   'Total operating revenue': 3030629.55,
#   'Employees': 487.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 61.59,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 20.2,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0001139445,
#   'Relative_Growth': 7.95,
#   'cluster': 1},
#  {'Company': 'Parex Resources (Colombia) Ag Sucursal',
#   'Cash and Cash Equivalents': 204598.19,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -50.45,
#   'Operating Profit Trend (%)': -64.89,
#   'Property, plant and equipment': 2345038.11,
#   'Return on Assets (ROA) (%)': 13.02,
#   'Return on Equity (ROE) (%)': 35.19,
#   'Quick Ratio (x)': 0.36,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2832154.48,
#   'Employees': 374.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.02,
#   'Export_US': 62.67,
#   'Import_US': 2.44,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 20.2,
#   'Export_DE': 0.0,
#   'Import_DE': 0.11,
#   'Export_BR': 0.0,
#   'Import_BR': 5.54,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.04,
#   'Export_PA': 37.21,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 14.44,
#   'cluster': 1},
#  {'Company': 'U.A.E. de la Aeronautica Civil',
#   'Cash and Cash Equivalents': 91615.02,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 15.38,
#   'Operating Profit Trend (%)': 20.04,
#   'Property, plant and equipment': 840497.92,
#   'Return on Assets (ROA) (%)': 7.18,
#   'Return on Equity (ROE) (%)': 8.1,
#   'Quick Ratio (x)': 7.87,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2776200.2,
#   'Employees': 500.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.89,
#   'Export_US': 100.0,
#   'Import_US': 0.48,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Transporte y Almacenamiento',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': -4.66,
#   'cluster': 1},
#  {'Company': 'Terpel Exportaciones C.I S.A.S',
#   'Cash and Cash Equivalents': 42106.52,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 18.82,
#   'Operating Profit Trend (%)': -59.46,
#   'Property, plant and equipment': 0.0,
#   'Return on Assets (ROA) (%)': 0.53,
#   'Return on Equity (ROE) (%)': 3.38,
#   'Quick Ratio (x)': 0.63,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2701469.3,
#   'Employees': 3.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 26.73,
#   'Import_US': 0.0,
#   'Export_EC': 3.58,
#   'Import_EC': 0.0,
#   'Export_MX': 7.31,
#   'Import_MX': 0.0,
#   'Export_ES': 24.05,
#   'Import_ES': 0.0,
#   'Export_DE': 0.05,
#   'Import_DE': 0.0,
#   'Export_BR': 2.8,
#   'Import_BR': 0.0,
#   'Export_PE': 4.22,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 4.35,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 78.28,
#   'cluster': 0},
#  {'Company': 'Colombia Movil S A E S P',
#   'Cash and Cash Equivalents': 23302.54,
#   'Long term Debt': 572718.57,
#   'Net Sales Revenue Trend (%)': -0.05,
#   'Operating Profit Trend (%)': 110.54,
#   'Property, plant and equipment': 1354989.6,
#   'Return on Assets (ROA) (%)': -3.65,
#   'Return on Equity (ROE) (%)': -407.16,
#   'Quick Ratio (x)': 0.37,
#   'Short Term Debt': 385762.36,
#   'Total operating revenue': 2695937.15,
#   'Employees': 2397.0,
#   'Export_CN': 0.0,
#   'Import_CN': 96.79,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 2.18,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Información y Tecnología',
#   'Debt_to_Assets': 0.7073714293,
#   'Relative_Growth': -110.59,
#   'cluster': 7},
#  {'Company': 'Hocol S.A.',
#   'Cash and Cash Equivalents': 80904.34,
#   'Long term Debt': 70708.48,
#   'Net Sales Revenue Trend (%)': -14.52,
#   'Operating Profit Trend (%)': -97.17,
#   'Property, plant and equipment': 889190.09,
#   'Return on Assets (ROA) (%)': 5.73,
#   'Return on Equity (ROE) (%)': 9.44,
#   'Quick Ratio (x)': 0.77,
#   'Short Term Debt': 96126.64,
#   'Total operating revenue': 2683049.9,
#   'Employees': 415.0,
#   'Export_CN': 0.0,
#   'Import_CN': 1.11,
#   'Export_US': 100.0,
#   'Import_US': 87.79,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.43,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.1876259327,
#   'Relative_Growth': 82.65,
#   'cluster': 1},
#  {'Company': 'Diana Corporacion S.A.S',
#   'Cash and Cash Equivalents': 7334.57,
#   'Long term Debt': 133202.76,
#   'Net Sales Revenue Trend (%)': 6.93,
#   'Operating Profit Trend (%)': 10.32,
#   'Property, plant and equipment': 537863.05,
#   'Return on Assets (ROA) (%)': -0.82,
#   'Return on Equity (ROE) (%)': -3.55,
#   'Quick Ratio (x)': 0.35,
#   'Short Term Debt': 634941.05,
#   'Total operating revenue': 2603130.87,
#   'Employees': 1731.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.01,
#   'Export_US': 0.0,
#   'Import_US': 7.46,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.13,
#   'Export_DE': 0.0,
#   'Import_DE': 0.04,
#   'Export_BR': 0.0,
#   'Import_BR': 8.78,
#   'Export_PE': 0.0,
#   'Import_PE': 14.55,
#   'Export_IT': 0.0,
#   'Import_IT': 1.71,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 1.4281401372,
#   'Relative_Growth': -3.39,
#   'cluster': 0},
#  {'Company': 'Teixeira Duarte - Engenharia E Construcoes, Sucursal en Colombia',
#   'Cash and Cash Equivalents': 146966.4,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 107.33,
#   'Operating Profit Trend (%)': -333.59,
#   'Property, plant and equipment': 374548.2,
#   'Return on Assets (ROA) (%)': -17.39,
#   'Return on Equity (ROE) (%)': 156.29,
#   'Quick Ratio (x)': 1.21,
#   'Short Term Debt': 583775.3,
#   'Total operating revenue': 2573619.3,
#   'Employees': 120.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.21,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.12,
#   'Export_DE': 0.0,
#   'Import_DE': 1.95,
#   'Export_BR': 0.0,
#   'Import_BR': 0.09,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 82.16,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Construcción',
#   'Debt_to_Assets': 1.558611949,
#   'Relative_Growth': 440.92,
#   'cluster': 17},
#  {'Company': 'General Motors - Colmotores S.A.',
#   'Cash and Cash Equivalents': 93336.15,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -27.56,
#   'Operating Profit Trend (%)': -199.1,
#   'Property, plant and equipment': 543694.76,
#   'Return on Assets (ROA) (%)': -10.01,
#   'Return on Equity (ROE) (%)': -36.73,
#   'Quick Ratio (x)': 0.2,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2564116.8,
#   'Employees': 602.0,
#   'Export_CN': 0.0,
#   'Import_CN': 10.17,
#   'Export_US': 0.17,
#   'Import_US': 12.55,
#   'Export_EC': 67.6,
#   'Import_EC': 0.04,
#   'Export_MX': 0.0,
#   'Import_MX': 10.43,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.03,
#   'Export_BR': 0.0,
#   'Import_BR': 27.32,
#   'Export_PE': 0.02,
#   'Import_PE': 0.01,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 171.54,
#   'cluster': 23},
#  {'Company': 'Teleperformance Colombia S A S',
#   'Cash and Cash Equivalents': 53260.58,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 1.94,
#   'Operating Profit Trend (%)': -25.6,
#   'Property, plant and equipment': 146692.36,
#   'Return on Assets (ROA) (%)': 7.7,
#   'Return on Equity (ROE) (%)': 12.45,
#   'Quick Ratio (x)': 2.38,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2555695.43,
#   'Employees': 21927.0,
#   'Export_CN': 0.0,
#   'Import_CN': 21.98,
#   'Export_US': 0.0,
#   'Import_US': 8.79,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Información y Tecnología',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 27.54,
#   'cluster': 0},
#  {'Company': 'Apple Colombia Sas',
#   'Cash and Cash Equivalents': 96048.6,
#   'Long term Debt': 3794.78,
#   'Net Sales Revenue Trend (%)': 12.83,
#   'Operating Profit Trend (%)': 96.54,
#   'Property, plant and equipment': 19632.54,
#   'Return on Assets (ROA) (%)': 19.31,
#   'Return on Equity (ROE) (%)': 88.15,
#   'Quick Ratio (x)': 1.22,
#   'Short Term Debt': 1363.77,
#   'Total operating revenue': 2365711.1,
#   'Employees': 50.0,
#   'Export_CN': 0.0,
#   'Import_CN': 93.58,
#   'Export_US': 100.0,
#   'Import_US': 0.05,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.11,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.2627550994,
#   'Relative_Growth': -83.71,
#   'cluster': 1},
#  {'Company': 'Cerro Matoso S A',
#   'Cash and Cash Equivalents': 150707.0,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -40.67,
#   'Operating Profit Trend (%)': -89.46,
#   'Property, plant and equipment': 1139411.0,
#   'Return on Assets (ROA) (%)': 8.82,
#   'Return on Equity (ROE) (%)': 20.12,
#   'Quick Ratio (x)': 1.63,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 2322628.0,
#   'Employees': 964.0,
#   'Export_CN': 48.04,
#   'Import_CN': 4.43,
#   'Export_US': 2.77,
#   'Import_US': 20.56,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 2.15,
#   'Export_ES': 2.36,
#   'Import_ES': 4.0,
#   'Export_DE': 0.0,
#   'Import_DE': 5.73,
#   'Export_BR': 0.0,
#   'Import_BR': 42.32,
#   'Export_PE': 0.0,
#   'Import_PE': 0.03,
#   'Export_IT': 6.34,
#   'Import_IT': 10.92,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Minería y Extracción',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 48.79,
#   'cluster': 3},
#  {'Company': 'Compania de Medicina Prepagada Colsanitas S A',
#   'Cash and Cash Equivalents': 594510.0,
#   'Long term Debt': 13585.37,
#   'Net Sales Revenue Trend (%)': 15.85,
#   'Operating Profit Trend (%)': 35.96,
#   'Property, plant and equipment': 41472.15,
#   'Return on Assets (ROA) (%)': -0.11,
#   'Return on Equity (ROE) (%)': -0.25,
#   'Quick Ratio (x)': 1.51,
#   'Short Term Debt': 488681.0,
#   'Total operating revenue': 2301000.0,
#   'Employees': 2241.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
# ...
#   'Return on Equity (ROE) (%)': 34.93,
#   'Quick Ratio (x)': 1.18,
#   'Short Term Debt': 7544.42,
#   'Total operating revenue': 103813.47,
#   'Employees': 543.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Profesionales y Técnicos',
#   'Debt_to_Assets': 0.4744012167,
#   'Relative_Growth': 46.27,
#   'cluster': 0},
#  {'Company': 'Milenio Pc S.A.',
#   'Cash and Cash Equivalents': 10815.42,
#   'Long term Debt': 293.75,
#   'Net Sales Revenue Trend (%)': 3.11,
#   'Operating Profit Trend (%)': -11.99,
#   'Property, plant and equipment': 90674.39,
#   'Return on Assets (ROA) (%)': 21.37,
#   'Return on Equity (ROE) (%)': 25.47,
#   'Quick Ratio (x)': 1.65,
#   'Short Term Debt': 643.33,
#   'Total operating revenue': 103779.29,
#   'Employees': 162.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Bienes Raíces',
#   'Debt_to_Assets': 0.0103345608,
#   'Relative_Growth': 15.1,
#   'cluster': 0},
#  {'Company': 'Logicalis Colombia S A S',
#   'Cash and Cash Equivalents': 7164.02,
#   'Long term Debt': 2655.71,
#   'Net Sales Revenue Trend (%)': 26.67,
#   'Operating Profit Trend (%)': 439.65,
#   'Property, plant and equipment': 291.42,
#   'Return on Assets (ROA) (%)': 10.84,
#   'Return on Equity (ROE) (%)': 75.21,
#   'Quick Ratio (x)': 1.04,
#   'Short Term Debt': 8055.73,
#   'Total operating revenue': 103446.58,
#   'Employees': 89.0,
#   'Export_CN': 0.0,
#   'Import_CN': 19.1,
#   'Export_US': 100.0,
#   'Import_US': 10.1,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 63.32,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 36.7560222359,
#   'Relative_Growth': -412.98,
#   'cluster': 1},
#  {'Company': 'Imagiq S A S',
#   'Cash and Cash Equivalents': 3277.06,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -37.79,
#   'Operating Profit Trend (%)': -50.19,
#   'Property, plant and equipment': 8727.43,
#   'Return on Assets (ROA) (%)': 5.55,
#   'Return on Equity (ROE) (%)': 9.42,
#   'Quick Ratio (x)': 1.27,
#   'Short Term Debt': 980.78,
#   'Total operating revenue': 103156.07,
#   'Employees': 99.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.1123790165,
#   'Relative_Growth': 12.4,
#   'cluster': 0},
#  {'Company': 'Pear Solutions S.A.S.',
#   'Cash and Cash Equivalents': 10903.92,
#   'Long term Debt': 12863.19,
#   'Net Sales Revenue Trend (%)': -5.91,
#   'Operating Profit Trend (%)': -9.74,
#   'Property, plant and equipment': 11616.53,
#   'Return on Assets (ROA) (%)': 1.62,
#   'Return on Equity (ROE) (%)': 3.37,
#   'Quick Ratio (x)': 2.02,
#   'Short Term Debt': 4238.74,
#   'Total operating revenue': 103149.43,
#   'Employees': 988.0,
#   'Export_CN': 0.0,
#   'Import_CN': 6.69,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Profesionales y Técnicos',
#   'Debt_to_Assets': 1.4722064162,
#   'Relative_Growth': 3.83,
#   'cluster': 0},
#  {'Company': 'Filmtex S A S',
#   'Cash and Cash Equivalents': 53.7,
#   'Long term Debt': 3976.98,
#   'Net Sales Revenue Trend (%)': -26.62,
#   'Operating Profit Trend (%)': -84.14,
#   'Property, plant and equipment': 42645.37,
#   'Return on Assets (ROA) (%)': -1.34,
#   'Return on Equity (ROE) (%)': -2.24,
#   'Quick Ratio (x)': 1.46,
#   'Short Term Debt': 27743.94,
#   'Total operating revenue': 103119.03,
#   'Employees': 190.0,
#   'Export_CN': 0.0,
#   'Import_CN': 1.58,
#   'Export_US': 13.21,
#   'Import_US': 22.75,
#   'Export_EC': 13.29,
#   'Import_EC': 0.0,
#   'Export_MX': 9.88,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.49,
#   'Export_DE': 0.0,
#   'Import_DE': 14.73,
#   'Export_BR': 3.0,
#   'Import_BR': 19.78,
#   'Export_PE': 8.67,
#   'Import_PE': 0.0,
#   'Export_IT': 0.12,
#   'Import_IT': 3.98,
#   'Export_PA': 0.23,
#   'Import_PA': 3.51,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.7438303384,
#   'Relative_Growth': 57.52,
#   'cluster': 0},
#  {'Company': 'Plasticos Tecnicos S.A.S.',
#   'Cash and Cash Equivalents': 10810.3,
#   'Long term Debt': 8590.09,
#   'Net Sales Revenue Trend (%)': 5.51,
#   'Operating Profit Trend (%)': 11.22,
#   'Property, plant and equipment': 28506.78,
#   'Return on Assets (ROA) (%)': 8.49,
#   'Return on Equity (ROE) (%)': 20.01,
#   'Quick Ratio (x)': 0.84,
#   'Short Term Debt': 22744.4,
#   'Total operating revenue': 102592.5,
#   'Employees': 584.0,
#   'Export_CN': 0.0,
#   'Import_CN': 15.91,
#   'Export_US': 37.2,
#   'Import_US': 12.73,
#   'Export_EC': 14.34,
#   'Import_EC': 0.0,
#   'Export_MX': 6.47,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 31.87,
#   'Export_BR': 16.91,
#   'Import_BR': 2.1,
#   'Export_PE': 0.24,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 6.91,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 1.0991942969,
#   'Relative_Growth': -5.71,
#   'cluster': 0},
#  {'Company': 'Dispetrocom S.A.S',
#   'Cash and Cash Equivalents': 3895.06,
#   'Long term Debt': 2225.21,
#   'Net Sales Revenue Trend (%)': 29.37,
#   'Operating Profit Trend (%)': 27.7,
#   'Property, plant and equipment': 7445.69,
#   'Return on Assets (ROA) (%)': 2.41,
#   'Return on Equity (ROE) (%)': 18.46,
#   'Quick Ratio (x)': 0.87,
#   'Short Term Debt': 411.37,
#   'Total operating revenue': 102282.01,
#   'Employees': 65.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.3541082156,
#   'Relative_Growth': 1.67,
#   'cluster': 0},
#  {'Company': 'Acqua Marketing Colombia S.A.S',
#   'Cash and Cash Equivalents': 4818.69,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -1.31,
#   'Operating Profit Trend (%)': -41.1,
#   'Property, plant and equipment': 3056.94,
#   'Return on Assets (ROA) (%)': 14.08,
#   'Return on Equity (ROE) (%)': 27.39,
#   'Quick Ratio (x)': 0.44,
#   'Short Term Debt': 17.6,
#   'Total operating revenue': 102132.75,
#   'Employees': 233.0,
#   'Export_CN': 0.0,
#   'Import_CN': 50.02,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 100.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.0057573914,
#   'Relative_Growth': 39.79,
#   'cluster': 7},
#  {'Company': 'Tivit Colombia Tercerizacion de Procesos Servicios y Tecnologia Sas',
#   'Cash and Cash Equivalents': 3137.83,
#   'Long term Debt': 6075.99,
#   'Net Sales Revenue Trend (%)': 15.23,
#   'Operating Profit Trend (%)': -14.55,
#   'Property, plant and equipment': 10742.18,
#   'Return on Assets (ROA) (%)': 5.02,
#   'Return on Equity (ROE) (%)': 9.09,
#   'Quick Ratio (x)': 1.28,
#   'Short Term Debt': 25626.09,
#   'Total operating revenue': 102000.63,
#   'Employees': 652.0,
#   'Export_CN': 0.0,
#   'Import_CN': 100.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Profesionales y Técnicos',
#   'Debt_to_Assets': 2.9511775077,
#   'Relative_Growth': 29.78,
#   'cluster': 7},
#  {'Company': 'Sony Music Entertainment Colombia S.A.',
#   'Cash and Cash Equivalents': 6675.85,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 5.5,
#   'Operating Profit Trend (%)': -2.14,
#   'Property, plant and equipment': 11121.87,
#   'Return on Assets (ROA) (%)': 8.08,
#   'Return on Equity (ROE) (%)': 30.52,
#   'Quick Ratio (x)': 0.49,
#   'Short Term Debt': 6415.01,
#   'Total operating revenue': 101729.63,
#   'Employees': 59.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 65.12,
#   'Export_EC': 45.99,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 15.38,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Información y Tecnología',
#   'Debt_to_Assets': 0.5767923919,
#   'Relative_Growth': 7.64,
#   'cluster': 10},
#  {'Company': 'Maple Respiratory I.P.S. S.A.S.',
#   'Cash and Cash Equivalents': 1979.87,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 31.35,
#   'Operating Profit Trend (%)': 46.46,
#   'Property, plant and equipment': 63034.67,
#   'Return on Assets (ROA) (%)': 14.08,
#   'Return on Equity (ROE) (%)': 23.37,
#   'Quick Ratio (x)': 0.97,
#   'Short Term Debt': 24153.95,
#   'Total operating revenue': 101519.0,
#   'Employees': 274.0,
#   'Export_CN': 0.0,
#   'Import_CN': 12.67,
#   'Export_US': 100.0,
#   'Import_US': 3.74,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 36.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.27,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Salud y Asistencia Social',
#   'Debt_to_Assets': 0.3831851583,
#   'Relative_Growth': -15.11,
#   'cluster': 1},
#  {'Company': 'Servicios Geologicos Integrados Sas. S. G. I. Sas',
#   'Cash and Cash Equivalents': 11337.6,
#   'Long term Debt': 1592.15,
#   'Net Sales Revenue Trend (%)': 2.3,
#   'Operating Profit Trend (%)': 8.15,
#   'Property, plant and equipment': 9855.22,
#   'Return on Assets (ROA) (%)': 12.16,
#   'Return on Equity (ROE) (%)': 16.99,
#   'Quick Ratio (x)': 2.54,
#   'Short Term Debt': 69.73,
#   'Total operating revenue': 101435.96,
#   'Employees': 755.0,
#   'Export_CN': 0.0,
#   'Import_CN': 17.27,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Servicios Profesionales y Técnicos',
#   'Debt_to_Assets': 0.1686294167,
#   'Relative_Growth': -5.85,
#   'cluster': 0},
#  {'Company': 'Edgewell Personal Care Colombia S A S',
#   'Cash and Cash Equivalents': 21406.54,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': 7.2,
#   'Operating Profit Trend (%)': 173.91,
#   'Property, plant and equipment': 258.43,
#   'Return on Assets (ROA) (%)': 7.84,
#   'Return on Equity (ROE) (%)': 16.16,
#   'Quick Ratio (x)': 1.19,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 101393.27,
#   'Employees': 78.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.1,
#   'Export_US': 0.0,
#   'Import_US': 2.99,
#   'Export_EC': 17.42,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 96.82,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': -166.71,
#   'cluster': 0},
#  {'Company': 'Danisco Colombia Ltda',
#   'Cash and Cash Equivalents': 8103.38,
#   'Long term Debt': 3048.45,
#   'Net Sales Revenue Trend (%)': -11.72,
#   'Operating Profit Trend (%)': -110.96,
#   'Property, plant and equipment': 2841.41,
#   'Return on Assets (ROA) (%)': -2.41,
#   'Return on Equity (ROE) (%)': -3.96,
#   'Quick Ratio (x)': 1.68,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 100856.63,
#   'Employees': 58.0,
#   'Export_CN': 0.0,
#   'Import_CN': 7.72,
#   'Export_US': 3.42,
#   'Import_US': 20.1,
#   'Export_EC': 11.14,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 3.41,
#   'Export_ES': 0.0,
#   'Import_ES': 0.12,
#   'Export_DE': 0.0,
#   'Import_DE': 0.04,
#   'Export_BR': 1.98,
#   'Import_BR': 19.49,
#   'Export_PE': 11.84,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Mayorista',
#   'Debt_to_Assets': 1.0728652324,
#   'Relative_Growth': 99.24,
#   'cluster': 0},
#  {'Company': 'Creative Colors S A',
#   'Cash and Cash Equivalents': 19395.52,
#   'Long term Debt': 0.0,
#   'Net Sales Revenue Trend (%)': -5.93,
#   'Operating Profit Trend (%)': -22.82,
#   'Property, plant and equipment': 16044.31,
#   'Return on Assets (ROA) (%)': 35.83,
#   'Return on Equity (ROE) (%)': 46.88,
#   'Quick Ratio (x)': 2.2,
#   'Short Term Debt': 0.0,
#   'Total operating revenue': 100841.57,
#   'Employees': 176.0,
#   'Export_CN': 0.0,
#   'Import_CN': 35.03,
#   'Export_US': 0.0,
#   'Import_US': 1.5,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 4.64,
#   'Export_BR': 0.0,
#   'Import_BR': 38.04,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Manufactura',
#   'Debt_to_Assets': 0.0,
#   'Relative_Growth': 16.89,
#   'cluster': 19},
#  {'Company': 'Inversiones y Asesorias de Transportes Andino S A',
#   'Cash and Cash Equivalents': 340.78,
#   'Long term Debt': 13458.77,
#   'Net Sales Revenue Trend (%)': 45.34,
#   'Operating Profit Trend (%)': 66.18,
#   'Property, plant and equipment': 20933.61,
#   'Return on Assets (ROA) (%)': 0.66,
#   'Return on Equity (ROE) (%)': 3.2,
#   'Quick Ratio (x)': 1.59,
#   'Short Term Debt': 1178.86,
#   'Total operating revenue': 100711.91,
#   'Employees': 98.0,
#   'Export_CN': 0.0,
#   'Import_CN': 0.0,
#   'Export_US': 0.0,
#   'Import_US': 0.0,
#   'Export_EC': 0.0,
#   'Import_EC': 0.0,
#   'Export_MX': 0.0,
#   'Import_MX': 0.0,
#   'Export_ES': 0.0,
#   'Import_ES': 0.0,
#   'Export_DE': 0.0,
#   'Import_DE': 0.0,
#   'Export_BR': 0.0,
#   'Import_BR': 0.0,
#   'Export_PE': 0.0,
#   'Import_PE': 0.0,
#   'Export_IT': 0.0,
#   'Import_IT': 0.0,
#   'Export_PA': 0.0,
#   'Import_PA': 0.0,
#   'NAICS_Group': 'Comercio Minorista',
#   'Debt_to_Assets': 0.6992405992,
#   'Relative_Growth': -20.84,
#   'cluster': 0},
#  ...]

# %%
import json

with open('../datos/complete_payload.json', 'w') as json_file:
    json.dump(result_total, json_file, indent=4)

# %% [markdown]
# ### Pipeline

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import re
import joblib

naics_map = {
        '11': 'Agricultura, Pesca y Minería',
        '21': 'Minería y Extracción',
        '22': 'Servicios Públicos',
        '23': 'Construcción',
        '31': 'Manufactura',
        '32': 'Manufactura',
        '33': 'Manufactura',
        '42': 'Comercio Mayorista',
        '44': 'Comercio Minorista',
        '45': 'Comercio Minorista',
        '48': 'Transporte y Almacenamiento',
        '49': 'Transporte y Almacenamiento',
        '51': 'Información y Tecnología',
        '52': 'Finanzas y Seguros',
        '53': 'Bienes Raíces',
        '54': 'Servicios Profesionales y Técnicos',
        '55': 'Administración de Empresas',
        '56': 'Servicios Administrativos y Apoyo',
        '61': 'Educación',
        '62': 'Salud y Asistencia Social',
        '71': 'Arte, Entretenimiento y Recreación',
        '72': 'Alojamiento y Servicios Alimenticios',
        '81': 'Otros Servicios',
        '92': 'Administración Pública'
}

# 1. Carga de Datos
def load_data():
    return pd.read_excel("../datos/Export.xlsx", skiprows=7)

# 2. Selección Inicial de Variables (Basada en EDA)
def initial_variable_selection(df):
    # Variables seleccionadas según el EDA
    selected_variables = [
        "Company",
        "Cash and Cash Equivalents",    
        "Export",
        "Import",
        "Industry (NAICS)",
        "Long term Debt",
        "Net Sales Revenue Trend (%)",
        "Number of Employees",
        "Operating Profit Trend (%)",
        "Property, plant and equipment",
        "Return on Assets (ROA) (%)",
        "Return on Equity (ROE) (%)",
        "Quick Ratio (x)",
        "Short Term Debt",      
        "Total operating revenue",
    ]
    return df[selected_variables]

def clean_data(df):
    # Identificar columnas categóricas y numéricas
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    categorical_columns = df.select_dtypes(include=['object']).columns
    
    # Imputación para columnas numéricas
    if len(numeric_columns) > 0:
        numeric_imputer = SimpleImputer(strategy='median')
        df[numeric_columns] = pd.DataFrame(
            numeric_imputer.fit_transform(df[numeric_columns]),
            columns=numeric_columns,
            index=df.index
        )
    
    # Imputación para columnas categóricas
    if len(categorical_columns) > 0:
        categorical_imputer = SimpleImputer(strategy='most_frequent')
        df[categorical_columns] = pd.DataFrame(
            categorical_imputer.fit_transform(df[categorical_columns]),
            columns=categorical_columns,
            index=df.index
        )
    
    # Eliminar filas que aún contengan valores nulos
    df.dropna(inplace=True)
    return df


# 4. Transformación de Datos
def transform_data(df):
    # Evitar divisiones por cero
    df['Property, plant and equipment'] = df['Property, plant and equipment'].replace(0, np.nan)
    df['Debt_to_Assets'] = (df['Long term Debt'] + df['Short Term Debt']) / df['Property, plant and equipment']
    df['Relative_Growth'] = df['Net Sales Revenue Trend (%)'] - df['Operating Profit Trend (%)']
    
    # Reemplazar infinitos y NaN generados
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    df.fillna(0, inplace=True)  # Rellenar valores faltantes con 0 después de las transformaciones
    return df

# 5. Preprocesamiento y Normalización
def prepare_pipeline(df):
    # Identificar columnas categóricas y numéricas
    categorical_features = df.select_dtypes(include=['object']).columns.tolist()
    numeric_features = df.select_dtypes(include=['float64']).columns.tolist()
    
    # Preprocesamiento para variables numéricas
    numeric_transformer = Pipeline(steps=[
        ('scaler', StandardScaler())
    ])
    
    # Preprocesamiento para variables categóricas
    categorical_transformer = Pipeline(steps=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])
    
    # Combinar preprocesamiento
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features),
            ('cat', categorical_transformer, categorical_features)
        ],
        remainder='drop'  # Eliminar columnas no especificadas
    )
    return preprocessor

# Función para extraer los países y porcentajes con expresiones regulares
def extract_countries_values_regex(column):
    country_dict = {}
    for row in column.dropna():
        # Buscar todas las ocurrencias del patrón 'PAIS (Porcentaje%)' o 'PAIS'
        matches = re.findall(r'([A-Za-z\s]+)(?:\s*\(([\d.]+)%\))?', row)
        for country, percentage in matches:
            country = country.strip()
            if percentage:
                percentage = float(percentage)
            else:
                percentage = 0.0  # Si no hay porcentaje, asignamos 0.0
            country_dict[country] = country_dict.get(country, 0) + percentage
    return country_dict

# Función para extraer los porcentajes de un item
def extract_percentage_from_item(item):
    try:
        # Verificar si el item contiene un porcentaje, de lo contrario devolver 0.0
        if '(' in item and ')' in item:
            return float(item.split('(')[1].replace('%', '').replace(')', '').strip())
        else:
            return 0.0
    except (IndexError, ValueError):
        return 0.0  # Manejo de errores si no es posible convertir el porcentaje

def import_export_preprocessing(datos):
    # Empleados
    datos['Employees'] = datos['Number of Employees'].str.extract(r'([\d,]+)\s\(\d{4}\)')
    datos['Employees'] = datos['Employees'].str.replace(',', '').replace('', np.nan).astype(float)
 
    # Lista de países específicos para importación y exportación
    countries = ['CN', 'US', 'EC', 'MX', 'ES', 'DE', 'BR', 'PE', 'IT', 'PA']
 
    # Generar nuevas columnas solo para los países especificados
    for country in countries:
        datos[f'Export_{country}'] = datos['Export']. \
            apply(
                lambda x: extract_percentage_from_item(
                    [item for item in x.split(',') if country in item][0]
                ) if isinstance(x, str) and any(country in item for item in x.split(',')) else 0.0
            )
        datos[f'Import_{country}'] = datos['Import']. \
            apply(
                lambda x: extract_percentage_from_item(
                    [item for item in x.split(',') if country in item][0]
                ) if isinstance(x, str) and any(country in item for item in x.split(',')) else 0.0
            )
    # Eliminar columnas no necesarias
    datos = datos.drop(["Import", "Export", "Number of Employees"], axis=1)
 
    return datos


def get_first_NAICS(datos: pd.DataFrame):
    datos['Industry (NAICS)'] = datos['Industry (NAICS)'].fillna('').astype(str)
    datos['First_Sector'] = datos['Industry (NAICS)'].str.split(';').str[0]

    # Extraer los primeros dos dígitos de los códigos NAICS
    datos['NAICS_Sector'] = datos['First_Sector'].str.extract(r'\((\d{2})\d*\)')[0]
    # Mapear los sectores principales utilizando el diccionario
    datos['NAICS_Group'] = datos['NAICS_Sector'].map(naics_map)
    datos = datos.drop(['First_Sector', 'Industry (NAICS)', 'NAICS_Sector'], axis=1)

    return datos


# Pipeline Completo
def run_pipeline():
    # Carga de datos
    data = load_data()
    
    print(data.head(5))
    
    # Selección inicial de variables
    selected_data = initial_variable_selection(data)

    import_export_adjusted = import_export_preprocessing(selected_data)

    first_NAIC = get_first_NAICS(import_export_adjusted)
    
    # Limpieza de datos
    clean_data_df = clean_data(first_NAIC)
    
    # Transformación de datos
    transformed_data = transform_data(clean_data_df)

    # Reinicia el índice para evitar que sea considerado una columna
    transformed_data = transformed_data.reset_index(drop=True)

    # preprocessor = joblib.load('../datos/preprocessor.pkl')
    preprocessor = prepare_pipeline(transformed_data[transformed_data.columns[1:]])
    
    processed_data = preprocessor.fit_transform(transformed_data[transformed_data.columns[1:]])
    
    return processed_data, transformed_data

data_processed, data_transformed = run_pipeline()
